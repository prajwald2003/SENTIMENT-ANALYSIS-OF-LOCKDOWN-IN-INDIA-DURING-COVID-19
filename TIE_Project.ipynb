# %%
import pandas as pd
import numpy as np
import re
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
from textblob import TextBlob
import nltk
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
# !pip install wordcloud
from wordcloud import WordCloud
# !pip install scikit-learn
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (1.9.2)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.2.0)

# %%
df = pd.read_csv('/content/vaccination_tweets-final.csv')

# %%
df.head()
# Out:
#              id             name              Location  \
# 0  1.340000e+18          barjraj  Uttar Pradesh, India
# 1  1.340000e+18     ramdin verma                Mumbai
# 2  1.340000e+18  sharat chandran        Jodhpur, India
# 3  1.340000e+18  birender mandal      Gurugram, Bharat
# 4  1.340000e+18             amit      New Delhi, India
#
#                                     user_description      user_created  \
# 0  Aggregator of Asian American news; scanning di...  08-04-2009 17:52
# 1  Marketing dude, tech geek, heavy metal & '80s ...  21-09-2009 15:27
# 2                                     heil, hydra 🖐☺  25-06-2020 23:30
# 3  Hosting "CharlesAdlerTonight" Global News Radi...  10-09-2008 11:28
# 4  Citizen News Channel bringing you an alternati...  23-04-2020 17:58
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             405          1692             3247          False
# 1             834           666              178          False
# 2              10            88              155          False
# 3           49165          3933            21853           True
# 4             152           580             1473          False
#
#                date                                               text  \
# 0  20-12-2020 06:06  Same folks said daikon paste could treat a cyt...
# 1  13-12-2020 16:27  While the world has been on the wrong side of ...
# 2  12-12-2020 20:33  #coronavirus #SputnikV #AstraZeneca #PfizerBio...
# 3  12-12-2020 20:23  Facts are immutable, Senator, even when you're...
# 4  12-12-2020 20:17  Explain to me again why we need a vaccine @Bor...
#
#                                             hashtags               source  \
# 0                                 ['PfizerBioNTech']  Twitter for Android
# 1                                                NaN      Twitter Web App
# 2  ['coronavirus', 'SputnikV', 'AstraZeneca', 'Pf...  Twitter for Android
# 3                                                NaN      Twitter Web App
# 4     ['whereareallthesickpeople', 'PfizerBioNTech']   Twitter for iPhone
#
#    retweets  favorites  is_retweet
# 0         0          0       False
# 1         1          1       False
# 2         0          0       False
# 3       446       2129       False
# 4         0          0       False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11020 entries, 0 to 11019
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                11020 non-null  float64
#  1   name              11020 non-null  object
#  2   Location          11020 non-null  object
#  3   user_description  10341 non-null  object
#  4   user_created      11020 non-null  object
#  5   user_followers    11020 non-null  int64
#  6   user_friends      11020 non-null  int64
#  7   user_favourites   11020 non-null  int64
#  8   user_verified     11020 non-null  bool
#  9   date              11020 non-null  object
#  10  text              11020 non-null  object
#  11  hashtags          8438 non-null   object
#  12  source            11019 non-null  object
#  13  retweets          11020 non-null  int64
#  14  favorites         11020 non-null  int64
#  15  is_retweet        11020 non-null  bool
# dtypes: bool(2), float64(1), int64(5), object(8)
# memory usage: 1.2+ MB

# %%
df.isnull().sum()
# Out:
# id                     0
# name                   0
# Location               0
# user_description     679
# user_created           0
# user_followers         0
# user_friends           0
# user_favourites        0
# user_verified          0
# date                   0
# text                   0
# hashtags            2582
# source                 1
# retweets               0
# favorites              0
# is_retweet             0
# dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'name', 'Location', 'user_description', 'user_created',
#        'user_followers', 'user_friends', 'user_favourites', 'user_verified',
#        'date', 'text', 'hashtags', 'source', 'retweets', 'favorites',
#        'is_retweet'],
#       dtype='object')

# %%
text_df = df.drop(['id', 'name', 'Location', 'user_description', 'user_created',
       'user_followers', 'user_friends', 'user_favourites', 'user_verified',
       'date', 'hashtags', 'source', 'retweets', 'favorites',
       'is_retweet'], axis=1)
text_df.head()
# Out:
#                                                 text
# 0  Same folks said daikon paste could treat a cyt...
# 1  While the world has been on the wrong side of ...
# 2  #coronavirus #SputnikV #AstraZeneca #PfizerBio...
# 3  Facts are immutable, Senator, even when you're...
# 4  Explain to me again why we need a vaccine @Bor...

# %%
print(text_df['text'].iloc[0],"\n")
print(text_df['text'].iloc[1],"\n")
print(text_df['text'].iloc[2],"\n")
print(text_df['text'].iloc[3],"\n")
print(text_df['text'].iloc[4],"\n")
# Out:
# Same folks said daikon paste could treat a cytokine storm #PfizerBioNTech https://t.co/xeHhIMg1kF
#
# While the world has been on the wrong side of history this year, hopefully, the biggest vaccination effort we've ev… https://t.co/dlCHrZjkhm
#
# #coronavirus #SputnikV #AstraZeneca #PfizerBioNTech #Moderna #Covid_19 Russian vaccine is created to last 2-4 years… https://t.co/ieYlCKBr8P
#
# Facts are immutable, Senator, even when you're not ethically sturdy enough to acknowledge them. (1) You were born i… https://t.co/jqgV18kch4
#
# Explain to me again why we need a vaccine @BorisJohnson @MattHancock #whereareallthesickpeople #PfizerBioNTech… https://t.co/KxbSRoBEHq

# %%
text_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11020 entries, 0 to 11019
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    11020 non-null  object
# dtypes: object(1)
# memory usage: 86.2+ KB

# %%
print(df['text'].dtype)
df['text'] = df['text'].astype(str)
# Out:
# object

# %%
# !pip install neattext
import neattext.functions as nfx
# Out:
# Collecting neattext
#   Downloading neattext-0.1.3-py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.7/114.7 kB 2.2 MB/s eta 0:00:00
# Installing collected packages: neattext
# Successfully installed neattext-0.1.3

# %%
dir(nfx)
# Out:
# ['BTC_ADDRESS_REGEX',
#  'CURRENCY_REGEX',
#  'CURRENCY_SYMB_REGEX',
#  'Counter',
#  'DATE_REGEX',
#  'EMAIL_REGEX',
#  'EMOJI_REGEX',
#  'HASTAG_REGEX',
#  'MASTERCard_REGEX',
#  'MD5_SHA_REGEX',
#  'MOST_COMMON_PUNCT_REGEX',
#  'NUMBERS_REGEX',
#  'PHONE_REGEX',
#  'PoBOX_REGEX',
#  'SPECIAL_CHARACTERS_REGEX',
#  'STOPWORDS',
#  'STOPWORDS_de',
#  'STOPWORDS_en',
#  'STOPWORDS_es',
#  'STOPWORDS_fr',
#  'STOPWORDS_ru',
#  'STOPWORDS_yo',
#  'STREET_ADDRESS_REGEX',
#  'TextFrame',
#  'URL_PATTERN',
#  'USER_HANDLES_REGEX',
#  'VISACard_REGEX',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__generate_text',
#  '__loader__',
#  '__name__',
#  '__numbers_dict',
#  '__package__',
#  '__spec__',
#  '_lex_richness_herdan',
#  '_lex_richness_maas_ttr',
#  'clean_text',
#  'defaultdict',
#  'digit2words',
#  'extract_btc_address',
#  'extract_currencies',
#  'extract_currency_symbols',
#  'extract_dates',
#  'extract_emails',
#  'extract_emojis',
#  'extract_hashtags',
#  'extract_html_tags',
#  'extract_mastercard_addr',
#  'extract_md5sha',
#  'extract_numbers',
#  'extract_pattern',
#  'extract_phone_numbers',
#  'extract_postoffice_box',
#  'extract_shortwords',
#  'extract_special_characters',
#  'extract_stopwords',
#  'extract_street_address',
#  'extract_terms_in_bracket',
#  'extract_urls',
#  'extract_userhandles',
#  'extract_visacard_addr',
#  'fix_contractions',
#  'generate_sentence',
#  'hamming_distance',
#  'inverse_df',
#  'lexical_richness',
#  'markov_chain',
#  'math',
#  'nlargest',
#  'normalize',
#  'num2words',
#  'random',
#  're',
#  'read_txt',
#  'remove_accents',
#  'remove_bad_quotes',
#  'remove_btc_address',
#  'remove_currencies',
#  'remove_currency_symbols',
#  'remove_custom_pattern',
#  'remove_custom_words',
#  'remove_dates',
#  'remove_emails',
#  'remove_emojis',
#  'remove_hashtags',
#  'remove_html_tags',
#  'remove_mastercard_addr',
#  'remove_md5sha',
#  'remove_multiple_spaces',
#  'remove_non_ascii',
#  'remove_numbers',
#  'remove_phone_numbers',
#  'remove_postoffice_box',
#  'remove_puncts',
#  'remove_punctuations',
#  'remove_shortwords',
#  'remove_special_characters',
#  'remove_stopwords',
#  'remove_street_address',
#  'remove_terms_in_bracket',
#  'remove_urls',
#  'remove_userhandles',
#  'remove_visacard_addr',
#  'replace_bad_quotes',
#  'replace_currencies',
#  'replace_currency_symbols',
#  'replace_dates',
#  'replace_emails',
#  'replace_emojis',
#  'replace_numbers',
#  'replace_phone_numbers',
#  'replace_special_characters',
#  'replace_term',
#  'replace_urls',
#  'string',
#  'term_freq',
#  'to_txt',
#  'unicodedata',
#  'word_freq',
#  'word_length_freq']

# %%
df['text'].iloc[2]
# Out:
# '#coronavirus #SputnikV #AstraZeneca #PfizerBioNTech #Moderna #Covid_19 Russian vaccine is created to last 2-4 years… https://t.co/ieYlCKBr8P'

# %%
df.head()
# Out:
#              id             name              Location  \
# 0  1.340000e+18          barjraj  Uttar Pradesh, India
# 1  1.340000e+18     ramdin verma                Mumbai
# 2  1.340000e+18  sharat chandran        Jodhpur, India
# 3  1.340000e+18  birender mandal      Gurugram, Bharat
# 4  1.340000e+18             amit      New Delhi, India
#
#                                     user_description      user_created  \
# 0  Aggregator of Asian American news; scanning di...  08-04-2009 17:52
# 1  Marketing dude, tech geek, heavy metal & '80s ...  21-09-2009 15:27
# 2                                     heil, hydra 🖐☺  25-06-2020 23:30
# 3  Hosting "CharlesAdlerTonight" Global News Radi...  10-09-2008 11:28
# 4  Citizen News Channel bringing you an alternati...  23-04-2020 17:58
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             405          1692             3247          False
# 1             834           666              178          False
# 2              10            88              155          False
# 3           49165          3933            21853           True
# 4             152           580             1473          False
#
#                date                                               text  \
# 0  20-12-2020 06:06  Same folks said daikon paste could treat a cyt...
# 1  13-12-2020 16:27  While the world has been on the wrong side of ...
# 2  12-12-2020 20:33  #coronavirus #SputnikV #AstraZeneca #PfizerBio...
# 3  12-12-2020 20:23  Facts are immutable, Senator, even when you're...
# 4  12-12-2020 20:17  Explain to me again why we need a vaccine @Bor...
#
#                                             hashtags               source  \
# 0                                 ['PfizerBioNTech']  Twitter for Android
# 1                                                NaN      Twitter Web App
# 2  ['coronavirus', 'SputnikV', 'AstraZeneca', 'Pf...  Twitter for Android
# 3                                                NaN      Twitter Web App
# 4     ['whereareallthesickpeople', 'PfizerBioNTech']   Twitter for iPhone
#
#    retweets  favorites  is_retweet
# 0         0          0       False
# 1         1          1       False
# 2         0          0       False
# 3       446       2129       False
# 4         0          0       False

# %%
df['text'].apply(nfx.extract_hashtags)
# Out:
# 0                                        [#PfizerBioNTech]
# 1                                                       []
# 2        [#coronavirus, #SputnikV, #AstraZeneca, #Pfize...
# 3                                                       []
# 4            [#whereareallthesickpeople, #PfizerBioNTech…]
#                                ...
# 11015                                                   []
# 11016                                    [#PfizerBioNTech]
# 11017                                                   []
# 11018               [#PfizerBioNTech, #Paxlovid, #COVID19]
# 11019                                                   []
# Name: text, Length: 11020, dtype: object

# %%
df['extracted_hashtags'] = df['text'].apply(nfx.extract_hashtags)

# %%
df[['extracted_hashtags','hashtags']]
# Out:
#                                       extracted_hashtags  \
# 0                                      [#PfizerBioNTech]
# 1                                                     []
# 2      [#coronavirus, #SputnikV, #AstraZeneca, #Pfize...
# 3                                                     []
# 4          [#whereareallthesickpeople, #PfizerBioNTech…]
# ...                                                  ...
# 11015                                                 []
# 11016                                  [#PfizerBioNTech]
# 11017                                                 []
# 11018             [#PfizerBioNTech, #Paxlovid, #COVID19]
# 11019                                                 []
#
#                                                 hashtags
# 0                                     ['PfizerBioNTech']
# 1                                                    NaN
# 2      ['coronavirus', 'SputnikV', 'AstraZeneca', 'Pf...
# 3                                                    NaN
# 4         ['whereareallthesickpeople', 'PfizerBioNTech']
# ...                                                  ...
# 11015                                                NaN
# 11016                                 ['PfizerBioNTech']
# 11017                                                NaN
# 11018          ['PfizerBioNTech', 'Paxlovid', 'COVID19']
# 11019                                                NaN
#
# [11020 rows x 2 columns]

# %%
# Cleaning Text
df['clean_tweet'] = df['text'].apply(nfx.remove_hashtags)

# %%
df[['text','clean_tweet']]
# Out:
#                                                     text  \
# 0      Same folks said daikon paste could treat a cyt...
# 1      While the world has been on the wrong side of ...
# 2      #coronavirus #SputnikV #AstraZeneca #PfizerBio...
# 3      Facts are immutable, Senator, even when you're...
# 4      Explain to me again why we need a vaccine @Bor...
# ...                                                  ...
# 11015  The number of Covid-19 cases today, 17 Novembe...
# 11016                      First dose ✅\n#PfizerBioNTech
# 11017  The number of Covid-19 cases today, 16 Novembe...
# 11018  #PfizerBioNTech has developed new pill #Paxlov...
# 11019  The number of Covid-19 cases today, 15 Novembe...
#
#                                              clean_tweet
# 0      Same folks said daikon paste could treat a cyt...
# 1      While the world has been on the wrong side of ...
# 2                  Russian vaccine is created to last...
# 3      Facts are immutable, Senator, even when you're...
# 4      Explain to me again why we need a vaccine @Bor...
# ...                                                  ...
# 11015  The number of Covid-19 cases today, 17 Novembe...
# 11016                                    First dose ✅\n
# 11017  The number of Covid-19 cases today, 16 Novembe...
# 11018    has developed new pill   that increased the ...
# 11019  The number of Covid-19 cases today, 15 Novembe...
#
# [11020 rows x 2 columns]

# %%
df['clean_tweet'] = df['clean_tweet'].apply(lambda x: nfx.remove_userhandles(x))

# %%
df[['text','clean_tweet']]
# Out:
#                                                     text  \
# 0      Same folks said daikon paste could treat a cyt...
# 1      While the world has been on the wrong side of ...
# 2      #coronavirus #SputnikV #AstraZeneca #PfizerBio...
# 3      Facts are immutable, Senator, even when you're...
# 4      Explain to me again why we need a vaccine @Bor...
# ...                                                  ...
# 11015  The number of Covid-19 cases today, 17 Novembe...
# 11016                      First dose ✅\n#PfizerBioNTech
# 11017  The number of Covid-19 cases today, 16 Novembe...
# 11018  #PfizerBioNTech has developed new pill #Paxlov...
# 11019  The number of Covid-19 cases today, 15 Novembe...
#
#                                              clean_tweet
# 0      Same folks said daikon paste could treat a cyt...
# 1      While the world has been on the wrong side of ...
# 2                  Russian vaccine is created to last...
# 3      Facts are immutable, Senator, even when you're...
# 4      Explain to me again why we need a vaccine     ...
# ...                                                  ...
# 11015  The number of Covid-19 cases today, 17 Novembe...
# 11016                                    First dose ✅\n
# 11017  The number of Covid-19 cases today, 16 Novembe...
# 11018    has developed new pill   that increased the ...
# 11019  The number of Covid-19 cases today, 15 Novembe...
#
# [11020 rows x 2 columns]

# %%
df['clean_tweet'].iloc[10]
# Out:
# 'while deaths are closing in on the 300,000 mark... millions of people wait     !\n-\nThe first U… https://t.co/uQ3A2f7SVP'

# %%
df['clean_tweet'] = df['clean_tweet'].apply(nfx.remove_multiple_spaces)

# %%
df['clean_tweet'].iloc[10]
# Out:
# 'while deaths are closing in on the 300,000 mark... millions of people wait !\n-\nThe first U… https://t.co/uQ3A2f7SVP'

# %%
df['clean_tweet'] = df['clean_tweet'].apply(nfx.remove_urls)

# %%
df['clean_tweet'] = df['clean_tweet'].apply(nfx.remove_puncts)

# %%
df[['text','clean_tweet']]
# Out:
#                                                     text  \
# 0      Same folks said daikon paste could treat a cyt...
# 1      While the world has been on the wrong side of ...
# 2      #coronavirus #SputnikV #AstraZeneca #PfizerBio...
# 3      Facts are immutable, Senator, even when you're...
# 4      Explain to me again why we need a vaccine @Bor...
# ...                                                  ...
# 11015  The number of Covid-19 cases today, 17 Novembe...
# 11016                      First dose ✅\n#PfizerBioNTech
# 11017  The number of Covid-19 cases today, 16 Novembe...
# 11018  #PfizerBioNTech has developed new pill #Paxlov...
# 11019  The number of Covid-19 cases today, 15 Novembe...
#
#                                              clean_tweet
# 0      Same folks said daikon paste could treat a cyt...
# 1      While the world has been on the wrong side of ...
# 2          Russian vaccine is created to last 24 years…
# 3      Facts are immutable Senator even when youre no...
# 4             Explain to me again why we need a vaccine
# ...                                                  ...
# 11015  The number of Covid19 cases today 17 November ...
# 11016                                      First dose ✅
# 11017  The number of Covid19 cases today 16 November ...
# 11018   has developed new pill that increased the cha...
# 11019  The number of Covid19 cases today 15 November ...
#
# [11020 rows x 2 columns]

# %%
from textblob import TextBlob

# %%
def get_sentiment(text):
    blob = TextBlob(text)
    sentiment_polarity = blob.sentiment.polarity
    sentiment_subjectivity = blob.sentiment.subjectivity
    if sentiment_polarity > 0:
        sentiment_label = 'Positive'
    elif sentiment_polarity < 0:
        sentiment_label = 'Negative'
    else:
        sentiment_label = 'Neutral'
    result = {'polarity':sentiment_polarity,
              'subjectivity':sentiment_subjectivity,
              'sentiment':sentiment_label}
    return result

# %%
ex1 = df['clean_tweet'].iloc[0]

# %%
get_sentiment(ex1)
# Out:
# {'polarity': 0.0, 'subjectivity': 0.125, 'sentiment': 'Neutral'}

# %%
df['sentiment_results'] = df['clean_tweet'].apply(get_sentiment)

# %%
df['sentiment_results']
# Out:
# 0        {'polarity': 0.0, 'subjectivity': 0.125, 'sent...
# 1        {'polarity': -0.5, 'subjectivity': 0.9, 'senti...
# 2        {'polarity': 0.0, 'subjectivity': 0.0333333333...
# 3        {'polarity': -0.05, 'subjectivity': 0.55, 'sen...
# 4        {'polarity': 0.0, 'subjectivity': 0.0, 'sentim...
#                                ...
# 11015    {'polarity': 0.0, 'subjectivity': 0.0, 'sentim...
# 11016    {'polarity': 0.25, 'subjectivity': 0.333333333...
# 11017    {'polarity': 0.0, 'subjectivity': 0.0, 'sentim...
# 11018    {'polarity': -0.12121212121212122, 'subjectivi...
# 11019    {'polarity': 0.0, 'subjectivity': 0.0, 'sentim...
# Name: sentiment_results, Length: 11020, dtype: object

# %%
df['sentiment_results'].iloc[0]
# Out:
# {'polarity': 0.0, 'subjectivity': 0.125, 'sentiment': 'Neutral'}

# %%
pd.json_normalize(df['sentiment_results'].iloc[0])
# Out:
#    polarity  subjectivity sentiment
# 0       0.0         0.125   Neutral

# %%
df = df.join(pd.json_normalize(df['sentiment_results']))

# %%
df.head()
# Out:
#              id             name              Location  \
# 0  1.340000e+18          barjraj  Uttar Pradesh, India
# 1  1.340000e+18     ramdin verma                Mumbai
# 2  1.340000e+18  sharat chandran        Jodhpur, India
# 3  1.340000e+18  birender mandal      Gurugram, Bharat
# 4  1.340000e+18             amit      New Delhi, India
#
#                                     user_description      user_created  \
# 0  Aggregator of Asian American news; scanning di...  08-04-2009 17:52
# 1  Marketing dude, tech geek, heavy metal & '80s ...  21-09-2009 15:27
# 2                                     heil, hydra 🖐☺  25-06-2020 23:30
# 3  Hosting "CharlesAdlerTonight" Global News Radi...  10-09-2008 11:28
# 4  Citizen News Channel bringing you an alternati...  23-04-2020 17:58
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             405          1692             3247          False
# 1             834           666              178          False
# 2              10            88              155          False
# 3           49165          3933            21853           True
# 4             152           580             1473          False
#
#                date  ...               source retweets favorites  is_retweet  \
# 0  20-12-2020 06:06  ...  Twitter for Android        0         0       False
# 1  13-12-2020 16:27  ...      Twitter Web App        1         1       False
# 2  12-12-2020 20:33  ...  Twitter for Android        0         0       False
# 3  12-12-2020 20:23  ...      Twitter Web App      446      2129       False
# 4  12-12-2020 20:17  ...   Twitter for iPhone        0         0       False
#
#                                   extracted_hashtags  \
# 0                                  [#PfizerBioNTech]
# 1                                                 []
# 2  [#coronavirus, #SputnikV, #AstraZeneca, #Pfize...
# 3                                                 []
# 4      [#whereareallthesickpeople, #PfizerBioNTech…]
#
#                                          clean_tweet  \
# 0  Same folks said daikon paste could treat a cyt...
# 1  While the world has been on the wrong side of ...
# 2      Russian vaccine is created to last 24 years…
# 3  Facts are immutable Senator even when youre no...
# 4         Explain to me again why we need a vaccine
#
#                                    sentiment_results polarity subjectivity  \
# 0  {'polarity': 0.0, 'subjectivity': 0.125, 'sent...     0.00     0.125000
# 1  {'polarity': -0.5, 'subjectivity': 0.9, 'senti...    -0.50     0.900000
# 2  {'polarity': 0.0, 'subjectivity': 0.0333333333...     0.00     0.033333
# 3  {'polarity': -0.05, 'subjectivity': 0.55, 'sen...    -0.05     0.550000
# 4  {'polarity': 0.0, 'subjectivity': 0.0, 'sentim...     0.00     0.000000
#
#    sentiment
# 0    Neutral
# 1   Negative
# 2    Neutral
# 3   Negative
# 4    Neutral
#
# [5 rows x 22 columns]

# %%
df['sentiment'].value_counts()
# Out:
# Neutral     5243
# Positive    4638
# Negative    1139
# Name: sentiment, dtype: int64

# %%
df['sentiment'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
positive_tweet = df[df['sentiment'] == 'Positive']['clean_tweet']
neutral_tweet = df[df['sentiment'] == 'Neutral']['clean_tweet']
negative_tweet = df[df['sentiment'] == 'Negative']['clean_tweet']

# %%
positive_tweet
# Out:
# 5        Does anyone have any useful advice/guidance fo...
# 7        There have not been many bright days in 2020 b...
# 10       while deaths are closing in on the 300000 mark...
# 11                                 Best wishes to the US…
# 12       The agency also released new information for h...
#                                ...
# 11006     ~10% of children aged 511 have got a first sh...
# 11008    I am fully vaccinated 💯💉🦠 Thank you Magsingal ...
# 11012    Yes Children ages 5–11 years receive onethird ...
# 11013    And back to for the booster This time its afte...
# 11016                                        First dose ✅
# Name: clean_tweet, Length: 4638, dtype: object

# %%
positive_tweet_list = positive_tweet.apply(nfx.remove_stopwords).tolist()

# %%
negative_tweet_list = negative_tweet.apply(nfx.remove_stopwords).tolist()
neutral_tweet_list = neutral_tweet.apply(nfx.remove_stopwords).tolist()

# %%
positive_tweet_list
# Out:
# ['useful advice/guidance COVID vaccine safe whilst breastfeeding…',
#  'bright days 2020 best 1 winning',
#  'deaths closing 300000 mark millions people wait U…',
#  'Best wishes US…',
#  'agency released new information health care providers patients shipped millions d…',
#  'Trump announces rollout 24 hours Americans vaccinated against…',
#  'Coronavirus: Iran reports 8201 new cases 221 deaths 24 hours',
#  'paid approve sudden money makes world',
#  'Trump announces rollout 24 hours Americans vaccinated against…',
#  'Presenting Medical News/Advancement past week dont want miss',
#  'Interesting detailed article showing tested help d…',
#  '6 deaths far death worry 🤔',
#  'Trump announces rollout 24 hours Americans vaccinated against…',
#  'I’ve excited vaccine 💉💉💉',
#  'Building week’s ‘trial’ run extending vaccination 💉 programme week effort going b…',
#  'COVID19 vaccine doses arrived Oregon Watch 6am 9am tomorrow det…',
#  'great feeling big thank healthcare professionals scientists nurses doctors caregivers…',
#  'Members delivered morning',
#  'Getting dose weekend seeing r…',
#  'taking COVID19 vaccine available',
#  'New York state administered nontrial vaccine morning health care worker P…',
#  'ICU nurse Sandra Lindsay said proud Americans receive Pfizer…',
#  'Odd verb choice Doug hand observe welcome Anita Anand under…',
#  'Ontarian vaccinated minutes later PSW Anita Quidangen Toronto',
#  'weekend issued guidance pilots following use new for…',
#  'Surprised learn autoimmune conditions immunosuppressed advised receive the…',
#  'Vaccine Works article detailed explanation👇',
#  'new type vaccine man daft hurts ears listening biggest question…',
#  'COVID19 VACCINATIONS TODAY 🙌🏻 Thank stepping getting',
#  'personal support worker people receive a…',
#  'Legacy Health registered COVID19 vaccine…',
#  'KFDM’s/FOX 4’s Baptist hospital getting hand look Pfizer COVID19 vacci…',
#  'Canadian PM Justin Trudeau announced arrival vaccine vials country',
#  'vaccines receivers Momentous science Hope arrived',
#  'good news: doses vaccine arrived California night Gov Gav…',
#  'Supervising I’m torn politicians going first(ish) important is…',
#  'night arrived Canada speak vaccines admin…',
#  'Happy Cold Chain Day way vaccine distributed county',
#  'Received dose today feel privileged amp lucky p…',
#  'hospital work received vaccine IV room doses given state I’…',
#  'night welcomed 30K doses 🇨🇦 l…',
#  'nurse New York City Monday person United States receive corona…',
#  'nurse New York City Monday person United States receive coronavirus…',
#  'received shipment vaccine line healthcare…',
#  'It’s kind surreal vaccine dropping today',
#  'President Trump says vaccine United States administered',
#  'Vaccination campaign begins today Quebec Residents Maimonides seniors in…',
#  'Kudos UPS announced 13th involvement amp support distribution efforts',
#  'Tuna Container Freezers Ship Given New Role …',
#  'end sight coworkers getting doses to…',
#  'Sunday evening’s shipment initial 30000 doses Pfizer vaccine spread 14 dist…',
#  'Approves Pfizer Vaccine Shipment Expected End Says PM Lee Hsien Loong…',
#  'approvals vaccine: approves expects shots Decemb…',
#  'Pfizer coronavirus vaccine doses set arrive hospitals',
#  'vaccinated 11 million new cases confirmed past week death toll 30600…',
#  'Oh great thought wouldnt able Xmas btw heard radio Shropsh…',
#  'Monday Asian country approve said ex…',
#  'Singapore approves Pfizer vaccine south East Asian country approve vaccine Doses gi…',
#  'Excited tomorrow honoured exciting team administering primary care',
#  'approves shipment expected endDecember',
#  'Singapores plan tackle effective Early pandemicmore $1 bn set aside fo…',
#  'Singapore approves vaccine local use Vaccine safe use people aged 16 above…',
#  'Phase 3 begins Dec 28 vaccine arrive end Dec shots free a…',
#  'True question vaccines vaccine needs given 2 shots: a…',
#  'million arrived lastminute',
#  'I’m vaccine Tuesday super thrilled',
#  'start today according latest figures maximum cases (over 167 mil…',
#  'batch doses PfizerBioNTech’s COVID19 vaccine arrived Canada” PM Trudeau said Twitter…',
#  'start today according latest figures maximum cases (over 167 mil…',
#  'Good news vaccines arrived vaccines like coming',
#  'money Mr Mark Twain getting doses United States',
#  'Interesting approach 🇺🇲 🇬🇧 guidance v clear now: person history anaph…',
#  'PfizerBioNTech COVID19 Vaccine: Donald Trump Mike Pence amp Officials Offered Early Access Newly A…',
#  'safe thank 👍',
#  'near 2030 Premature innoculation 😇',
#  '🙏 batch doses vaccines YAY congratulations 🙏…',
#  'information vaccine severe allergies:',
#  'Welp thanks arent going planned distribution aren…',
#  'excellent news great President Trump administration pushed vaccine ready qui…',
#  'process definitely thought publicity wise',
#  'case interested link patient information t…',
#  'vaccines going officially allows',
#  'COVIDvaccine given green light',
#  'kind leave',
#  'Grateful group vaccinated healthcare workers Tampa/FL 🙏🏽…',
#  'Dr Kathy Lofy says vaccine new tool tool box says she’ll vaccinated soon as…',
#  'recommended use vaccine persons 16 years age older the…',
#  'Boxes containing shipment PfizerBioNTech prepared sent',
#  'great day Country amp World DAY CLOSER leaving first…',
#  'watched new correctly stated deaths o…',
#  'Apparently trucks escorted Marshals 🤞🤞 stay safe hijacking o…',
#  'newly approved start distributed states Dec 14 according of…',
#  'know Trumpkins like informed goes: 1) vaccine developed in…',
#  'firm Acuitas heart great story helped early wi…',
#  'trucks loaded Pfizer’s coronavirus shot pulled Michigan warehouse early Sunday — starting t…',
#  'Thanks bringing fresh air positivity God’s hand pushing forw…',
#  'shipment PfizerBioNTech coronavirus vaccine leaves Michigan facility',
#  'Happy relieved – amazing work since…',
#  'companies submitted applicat…',
#  'Food Drug Administration (FDA) issued yesterday emergency use authorization PfizerBioN…',
#  'COVID 19 Vaccination Latest Update',
#  '10 months 3 weeks case finally relief Uncle Sam Vaccination starts Monday👏…',
#  'trucks filled hit road 💉',
#  'Interesting Watch: live coverage loading vaccine Pfizer plant at…',
#  'people United Kingdom experienced allergic reaction Pfizer/BioNTech COVID19 vaccine Rea…',
#  '💉GPs struggling provide core services amp di…',
#  'shipments vaccine begin arriving states Monday offi…',
#  'numbers likely worse holidays offering bright spot fight the…',
#  'good work',
#  'Ok late discovering vaccines led by…',
#  'President Donald Trump announced vaccine free Americans thanked scienti…',
#  'hatched Canada (2) vaccine developed Germany (3) Scie…',
#  'hatched Canada (2) vaccine developed Germany (3) Scie…',
#  'Proving unproven time constraints hardest Great achievement Pfizer',
#  'love high quality infographics getting multiple ideas quickly excellent set Fact…',
#  'learn victory good refresher polio came end Lets forget…',
#  'Big Pharma best interests hold stock amp patients',
#  '🇬🇧 guidance clear now: person history anaphylaxis vaccine medicine o…',
#  'agency authorizes PfizerBioNTech COVID19 vaccine vaccine administered in…',
#  'New PODCAST: Vaccinating Way Pandemic amp discuss the…',
#  'Eric Shawn: vaccine record time thanks al…',
#  'Facts Senator nice respect faith tell truth vaccine dev…',
#  'coming Vaccine soon excited',
#  'relieved share I’ll receive Thank…',
#  'DYK: amp nations approve',
#  'Fascinating messenger RNA vaccine delivery approach helped enable dramatically shorter time to…',
#  'Vaccine discovered developed Europe TurkishGerman husband wife',
#  'Tiffany Dover alive 👀😃',
#  'important day f…',
#  'It’ll interesting postvaccine birth rates winter 😂',
#  'Singapore volunteer amp 16 immune suppressant takers amp pregnant portal Booklet kn…',
#  'Moderna vaccine need extra special handling requirements Pfizer includin…',
#  'mandated anthrax vaccine killed 35k soldiers* maimed 2% adverse reactions…',
#  'mRNA vaccines teach cells protein trigger immune response live vi…',
#  'vaccine special triggers immune response actual virus causes covid19…',
#  'Healthcare workers receive dosis PfizerBioNtech COVID19 vaccine Memorial Healthcare System Mir…',
#  'Excited received todayImpressive resource mobilization…',
#  '1000 Jackson employees successfully received dose vacci…',
#  'interesting learned interview today: Theres lot chatter how…',
#  'real cool🙏🏻😎',
#  'notice vaccinations NHS picture taken video actual vaccination Becau…',
#  'differ answer question t…',
#  'Jackson North Medical Center getting vaccine today',
#  'talking HUMAN LIVES Lets repeat mistake past jeopardized lives…',
#  'Thrilled receive dose Covid vaccine today vulnerable people visit support work with…',
#  'HAPPENED got dose vaccine today BEST HOLIDAY PRESENT Als…',
#  '🍁 T…',
#  'pleased vaccine 💉 important people possi…',
#  '9/ course people want sure clinical trial data available f…',
#  'MD Dr Susannah Thompson pulling stops leading magnificent team NHS staff amp volunteers tonight…',
#  'starting COVID vaccination program today Socially distanced staff patiently waiting',
#  '“I’m honored getting vaccinated Protect protect loved ones gettin…',
#  'proud team today officially started vaccinating worked extremely…',
#  'Vaccine Shots Watch video',
#  'contain live virus vaccine cause COVID19 disease possible',
#  'good thead epidemiologist',
#  'WATCH LIVE: System news conference receiving shipment COVID19 v…',
#  'Hav genuine place deliverin',
#  'year 2022 proudly post picture eventually receive covid vaccine…',
#  'little vial carries 🙏🏽to scientists worked tirelessly',
#  'Today lucky vaccinated patients my…',
#  'incredibly grateful received Thanks who…',
#  'Save best',
#  'Canada receiving 200000 doses vaccine week amp potentially 168…',
#  'Grossly unfair absolutely inevitable Dibs Vaccines Rich Countries ‘Cleared Shelves’…',
#  'juice loose Received 1st dose PfizerBioNtech vaccine today Proud medical worker th…',
#  'Feeling emotional grateful lucky people Worcestershire receive vaccine…',
#  'INFOGRAPHIC: declared possibility seven effects vaccine Read a…',
#  'Excited rolling today amazing work s…',
#  'process smooth easy step way able communicate st…',
#  'Thanks genius immigrant ( Trump amp GOP despise)',
#  'vaccine coming released report Live @ Noon w/ va…',
#  '😂😂😂 New strain what…',
#  'Ive provided short summary PfizerBioNTech publication New England Journal Medicine vacc…',
#  '‘myGP’ launch England’s digital COVID19 vaccination verification feature smartphones',
#  'COVID19: New York nurse gets shots Coronavirus Vaccine',
#  'Polish healthcare worker UK Polish person given vaccine COVID19…',
#  'Delighted taxi driver today gentleman early 90s GPs Covid vaccination (part 1 o…',
#  'EUs medicines regulator Tuesday dramatically advanced decision day the…',
#  'Ottawa County Calhoun County preparing administer entire shipment includes 97…',
#  'Vision immigrant (the kind hates)…',
#  'Getting ready segment discuss myths',
#  'Ready joined launch clinic incredible',
#  'VIDEO: Elderly patients Isle vaccinated',
#  'praising responsible Lets credit credi…',
#  '🤔 vaccine taking Coz bro asked didnt liked answer 😒I…',
#  'downone Excellent vaccination service thank 💉🦠',
#  'Celebrity cook presenter getting new vaccine West Oxfordshire today…',
#  'It’s great day science ☀️',
#  'guide safely Pfizer/BioNTech Covid19 vaccine',
#  'COVID19 vaccination New York Lev Radin',
#  'Thanks Becky 🙏🏻 learning Ou…',
#  '13 GP practices jab starts rolled ou…',
#  '🙏 sharing Extensive analysis vaccine safety profile line SAFE eg…',
#  'wasn’t Jennifer Haller person USA given trial vaccine given Person year…',
#  'Dose COVID19 Vaccine Given Black Nurse New York',
#  'Bhakts world boycott developed',
#  'doses Coronavirus vaccine administered Canada following UK',
#  'wonderer covid vaccine producers inc Chinese ones getting indemnity governme…',
#  '”Clearly beginning end sense end pande…',
#  'New York Monday inoculated healthcare worker vaccine YouTube…',
#  'line',
#  'I’m sure object Pfizer CEO getting vaccine prefer 1 the…',
#  'Ready tomorrow starting Ms Quidangen Canadian receive ready…',
#  'share latest case death projections forecast model acc…',
#  'Delighted packed dry ice heading worldthough me…',
#  'Unlike 🇬🇧 🇺🇲 giving mRNA vaccine pregnant woman amp allerg…',
#  'Months fighting Covid ICU grateful PPE covid free relief getti…',
#  'Getting island Today day giving vaccines liner…',
#  'San Bernardino County began administering doses vaccine…',
#  'little 24 h Im lucky symptoms extra ene…',
#  'Today aimed higher broke record Jackson administered 1278 vaccinations bringing o…',
#  'There’s light end tunnel proud incredible teamwork went making possible…',
#  'ICU Nurse Sonya Harrell receives dose San Bernardino County…',
#  'younger brother frontline ICU fellow getting shot o…',
#  '24 new deaths province reports 640 new cases 9 950 active cases New type measu…',
#  'Pfizer’s experimental covid19 vaccine —What you’re told desperat…',
#  'Hope humanity Important science nationality race ethnicity religion',
#  'Interesting🤔🤔 Explain: 59 years old good health line type is…',
#  'impressed heard 1st number earlier today Bit simple maths means wider pictur…',
#  'determine safe effective storage temperatures dipped 80°C',
#  'getting vaccine it’s available locality',
#  'Got COVID vaccine today amazing happy able Feels like world finally turn…',
#  'thanks e…',
#  'Vaccinated Painless injection I’m currently cruising social media 15 minute observation period…',
#  'comprised ingredients standard vaccines including mRNA lip…',
#  'case allergic reaction Pfizer Vaccine expected t…',
#  'Imagine pizzeria liable damages got pie poisoned damaging he…',
#  'appreciated IMMENSE unDithering',
#  'manages batch Pfizer Moderna vaccines poor countries Click more:',
#  'talented people developing countries forcefully stopped/barred fo…',
#  '👍 🌎 AWAITS mo…',
#  'According New York Times authorities alert new allergic reactions',
#  'According New York Times based anonymous sources health care professional history a…',
#  'amp maybe',
#  'taken world know amp 2020 🦠 Read help separat…',
#  'wants doses:',
#  'touching ampinspiring Forward 2020 covid19 Iam PROUD BRITISH AFRICA amp know th…',
#  'got COVID vaccine sit 15 minutes sure we’re okay far feel fine…',
#  'true news got vaccine dose Waiting 15 minutes can…',
#  'wiser vaccine risk complications new type vaccine wiser wait o…',
#  'Natural Selection Injection rid world of…',
#  '1/ Don’t fear needle(like did) Honored receive protect loved ones friends a…',
#  'good news 137000 vaccinated week UK',
#  'Today noon received dose Pfizer COVID19 vaccine Super exciting create thread h…',
#  'Moderna vaccine: Canada Federal officials deliver details COVID19 vaccines rollout',
#  'Canada: Alberta plans send COVID19 teams hardhit areas Edmonton Calgary | Indiablooms Portal on…',
#  'fair statesgenie bottle',
#  'nurse NYC people receive early dose PfizerBioNTech vaccine Monday mornin…',
#  'Relieved excited receive Happy report haven’t developed thi…',
#  'country South approve emergency use vaccine',
#  'authorized use vaccine countries in…',
#  'Day 1 getting feeling great little bit soreness my…',
#  'time finding people got shot Today day L…',
#  'Better Trials begin theyre JAN PRATINIDHI (जन प्रतिनिधि) Wh…',
#  'Greatest vaccination campaign history begins nurse given dose covid vaccine',
#  'video audio tour Final preparations checks live tomorrow Exciting times also…',
#  'Covid19 vaccine vaccine soon available Vaccinations save lives g…',
#  'know exactly bioNTech/Pfizer (or others) vaccine Ie help reduce symptoms…',
#  'vaccination family member moments ago Sisters daughter 😊',
#  'shot hope: Frontline health care workers receive COVID19 vaccinations',
#  '137897 people UK hav recd dose week large…',
#  'Starting today new chapter begins hospital filled hopes end dark COVID times amp joy o…',
#  'Debate right pace continues Europes press Pressure growing European Medicin…',
#  'lies saying UK country produce vaccine …',
#  'day team thanks staff going patients',
#  'start ready are…',
#  'Beautiful summary RNA vaccine works',
#  'presents unique challenges v low storage temp amp short period time…',
#  'wonderful interviewing misconceptions the…',
#  'jab hope today Feel privileged access quickly Hopefully beginning t…',
#  'Daphne Dye 89 shares joke clinical staff dose vaccine Clacton…',
#  'Happy new year',
#  '‼️ Allergic reactions vaccine: polyethylene glycol (PEG) culprit ‼️',
#  'Guys need add right 😬😋🤣',
#  'beginning end Tonight received Christmas Birthday present I’m ICU nurse y…',
#  'NEW TODAY: Hospitals administered Vaccine frontline medical staff The…',
#  'Incredibly honored draw COVID vaccine doses badass colleagues wait turn',
#  'Hear receiving vaccine…',
#  'Today received dose Pfizer COVID19 vaccine grateful Thanks employer my…',
#  'Arm little sore good way end sight',
#  'find hilarious conspiracy theorists guzzling colloidal silver afraid turning papa…',
#  'Hey folks able covid 19 vaccine trust erection…',
#  'Great success story based resillience visionary researchers',
#  '| Clearly race finishing line eyes market developers of…',
#  'saying causes harm control population thing Pfizer UK wa…',
#  'doses vaccine arrived today start with…',
#  'apparently come damaging effects pursue legal ac…',
#  'Feeling thankful hopeful tonight',
#  'Kessler Women’s Healthcare received dose coronavirus vaccine (Pfizer version)…',
#  'Got awaited moments daily updates Lot people doubts recomme…',
#  'Great trolling:',
#  'haven’t tested vaccine Pregnant Women Phase 3 low immune systems I…',
#  'Nearly 140000 people UK received shots week rollout vacci…',
#  'It’s pharmacy team unpacked shipment moving dose…',
#  'Possibly got dose Tuesday honestly pain…',
#  'Excited colleagues today he…',
#  'hospitals received batch 25000 doses Pfizer/BioNTech vaccine…',
#  'Day Great people starting smile hope great',
#  'Thanks President Reagan',
#  'Covid19 vaccine developed approved world starting w…',
#  'hot commodity vaccine thinking primarily f…',
#  'Veteran star received dose Covid19 vaccine says feeling euphoric abou…',
#  'LOL 🤦\u200d♂️🤷🏻🤷🏽\u200d♀️who fooling',
#  'important life decision taking vaccine',
#  'got I’m fight Thanks opportunity…',
#  'Airlines Early Vaccine Transports Moving Smoothly – Skift',
#  'Im gonna openly stalking people like Feel free share',
#  'fortunate PROUD yesterday thankful histo…',
#  'released positive analysis single dose prevent Si…',
#  'delivery PfizerBioNTech vaccine arrived Elmhurst Hospital early Thursday morning…',
#  'Singapore Asian country approve PfizerBioNTech coronavirus vaccine said expects…',
#  'Americans receive COVID19 vaccine amid historic rollout',
#  '$SVTE easily deliver right $PFE $BNTX',
#  'don’t professional darts players people I’m sure quicker and…',
#  'members (over 80) report structured amp fast process staff…',
#  'pretty sure ji got lets wear ge…',
#  'sets 24hour records 3700 Covid deaths 250000 new cases',
#  'safe Alaska medicos suffer severe allergic reaction jab',
#  'candidates appear promising interim results press release(which excellent)only…',
#  'Excellent thread O/T: opinion info UK possible mutation spike proteins just…',
#  'Theres lot Great vaccine reports disastrous effects amp 💣💣…',
#  'Gestapo Tory share vaccine want live video li…',
#  'Exactly 👇',
#  'Hey Piers adverse reactions US…',
#  '24 hours post honestly feeling great arm sore yesterday (usually so…',
#  'Swiss clear jab fight coronavirus',
#  'safety profile vaccine good – different ages ethnicities sexes i…',
#  'huge thank involved COVID vaccination programme Dose 1 2 Ensuring safety every…',
#  'morning I’ve given covid 19 vaccines 💉 great able offer support mass vaccination…',
#  'good video primer amp vaccines work “Rooted Science” Recommended',
#  'publicly people safe',
#  'Cool guys town',
#  'seen vaccine videos far havent seen aspirating injecting Isnt sm…',
#  'Feeling hopeful time 10 months immensely grateful working th…',
#  'Inequity new low 👇',
#  'Stay safe ❤️ We’ll end sight #',
#  'Excited line workers coming help fight pandemic Big tha…',
#  '24 hours post COVID vaccine 💉 feeling fine',
#  '11 new deaths province Friday announces 624 new cases 1376 doses',
#  'got Covid19 vaccine today',
#  '60 percent Saudis expats shown interest taking',
#  'Fascinating read scientist work paved way Covid vaccines',
#  'surreal moment got COVID19 vaccine morning continue wear mask practice so…',
#  'safe effective soon youre eligible',
#  'Happy tears Got dose Pfizer vaccine today reaction gave JOY',
#  'Thanks efforts United Kingdom approve rollout vaccine 💉 Scotland vaccinated pla…',
#  'Help American citizens information you’ve received vaccine Don’t forget t…',
#  'fan VP Mike Pence thank public needs strong leadership sides insti…',
#  'stepping amp right thing placebo recipients waiting sick…',
#  'Oh best explanation vaccine immune response',
#  'Strong work Science 5/5 High Honors',
#  'Dr Mark Poznansky joined discuss latest process…',
#  'Today day Feel lucky wave it’s turn receive',
#  'can’t tell happy images Seeing ICU ED nurse managers vaccinated brings suc…',
#  'historic event received shipment whi…',
#  'got vaccinated today feeling good',
#  'know €£$ EU countries pay vaccines (€12 dose thank Belgi…',
#  'dose 1 yesterday Thanks partnership w',
#  'Absolutely right supposed choice or…',
#  'Hope start better return way things fight beginning Hope…',
#  'dose vaccine arm 2nd dose 3 weeks',
#  'forever thankful science successfully producing vaccine 9 months p…',
#  'Finally light end tunnel ☀️',
#  '“Our challenge ensure vaccines treated public good – accessible affordable everyone…',
#  'Mauricette78 Pfizer GUINEA PIG French nursing home: “ah vaccine vaccinate p…',
#  'want list ingredients Pfizer covid vaccine',
#  'people actually got vaccine 6 days',
#  'absolute best things look I’m desk',
#  'hope received initial supplies got 2…',
#  '1st dose 1 Thank and…',
#  'covid vaccine actually got 800000 doses 4…',
#  'Benjamin Netanyahu health minister injected vaccine live TV…',
#  'Woo getting vaccine New Years Eve Going finish year hope',
#  'Day 1 feeling fine little sore injection site that’s',
#  'vaccine new virus mutation detected UK affect',
#  'believe conspiracy tweets Read report homework stay sheep Cov…',
#  'favorite people Saturday getting other…',
#  'Uh huh people kill vaccine adverse reaction n…',
#  'Feeling good',
#  'Public Health reporting 5 new cases new cases provinces active c…',
#  '',
#  'equity equitable distribution vaccine world people dev…',
#  'Big thanks scientific/clinical teams incredible feat \u2066 prioritiz…',
#  'Refusing doesn’t honest Development rushed amp phase 3 test…',
#  'took delivery Saturday 2 medical freezers store batch of…',
#  'says approval shot Saturday world’s authorization or…',
#  'relevant 🤣😂🤣😂🤣🤣',
#  'Fantastic Explainer: stacks \u2066',
#  'shipper box good solution 70 degree Celsius temperature',
#  'got safe effective COVID vaccine seriously best Christmas gift possible thanks b…',
#  'Nice wrapup vaccine administration approval process',
#  'delighted announce scientific committee met today recommended conditional ma…',
#  'good day EMA given approval widespread use',
#  'received delivery Monday…',
#  'Gov picked elderly test group Trudó respect ar…',
#  'vaccine approved MHRA FDA EMA want know vaccinated ASAP you…',
#  'Ready Set',
#  'Leading medial experts said existing vaccines COVID19 effective fighting infection fr…',
#  'excited shipment arrived Singapore',
#  'happening Don’t know vaccine geared new challenge sayi…',
#  'great summary evidence particularly helpful primary care…',
#  'feelings',
#  'like 1 jab 1 Thanks Dr Ammara Hughes vaccinating Helping 70% target for…',
#  'knows / vaccines efficiency vs new',
#  'Oman receive vaccine shipments Wednesday Al Arabiya',
#  'Crying happy tears mom works cardiology gone office day pandemic start…',
#  'Hey vaccine people :) find protein exactly Pfizer…',
#  'soon good have…',
#  'Doctors Nura Emir Festić: vaccinated brave ones',
#  'Particular freight concentrate = coming',
#  'Waiting wife receives dose',
#  'past criminal records company vaccinate promises happy monkey ne…',
#  'Woke early happy grateful— especially scientists clinical tria…',
#  'Right meeting reporting following 2838225 doses distribute…',
#  'Innoculation 1 thing knowing u r nt 100% safe frm claim 95% efficacy s…',
#  'Professor Eric Caumes says trusts amp Chinese developed vaccines reservations agai…',
#  'got Covid19 Vaccine 💉 dose 1 today I’ll let y’all know super powers tomorrow 12/21 😂😂…',
#  'Feeling fine 24 hours',
#  'image shared alongside claim shows clinical trial volunteers developed Bell…',
#  'Hold America 2 help crush virus wise decisions…',
#  'COVID19 vaccine mRNA morning',
#  'NHS staff resources support need tackle health crisis right suppl…',
#  'vaccine leaky doesnt stop transmission vaccinated people shed virus…',
#  'Day following Covid Vaccine Perfectly normal minor ache associated needle delt…',
#  'vaccinated getting vaccine soon Plan abroad best DMC reviews…',
#  'UK folks UK Govt lied order make…',
#  'quick blame West expect West trust refused…',
#  'stock Moderna bet don’t Pfizer stock Funny waiting for…',
#  '1800 people received today bringing total vaccinations our…',
#  'allergies lot things tolerating vaccine fine vaccine use a…',
#  'FDA investigating allergic reactions Pfizer shot | Reuters rare effect be…',
#  'jury don’t know amp vaccine…',
#  'Dear mr Trump stock market important mRNA vaccine experimental state wanna mandatory…',
#  'SL new Balto',
#  'Got dose Christmas Eve effect s…',
#  'leader brave step lead extremely fight serve people 🇸🇦 feel nothin…',
#  'got present HMC 😂 best 🎁 💉…',
#  'men died island prepares arrival',
#  'Researchers think compound / responsible allergic reactions Pfize…',
#  'received batch PfizerBioNTech shipment Thursday aircraft shipmen…',
#  'book appointment Vaccine available h…',
#  'Today got COVID19 vaccine 💉 light end tunnel💡 got know got be…',
#  'batch arrives',
#  'Sharing ingredients list interested Consider products ingest on/in bodies amp othe…',
#  'BREAKING: New arrived',
#  'Ah te sweet smell money Finally theyll tril…',
#  'Vaccinated 1st dose COVID19 Mild moderate local injection site effects…',
#  '600000 UK citizens received developed pharmaceutical companies…',
#  'Pfizer vaccine causing allergic reactions expected',
#  'country begin receiving first…',
#  'UAE: phase vaccination campaign launched Dubai Wedne…',
#  'UAE: phase vaccination campaign launched Dubai Wedne…',
#  'COVID19 Vaccination UK: 600000 Citizens Receive Dose PfizerBioNTech Vaccine…',
#  'National Authority Health said Thursday approved developed by…',
#  'amazing circle moment',
#  'Check latest article: Pediatrician Vaccine HesitancyMy Journey COVID Vaccine…',
#  'Today Wei Xu Personal Support Worker ( received dos…',
#  '600000 dose',
#  '600000 dose',
#  'effective Vaccines info:',
#  'vaccine licensed pregnant women',
#  'wonderful Christmas present Thank completely painless 🎄🥳',
#  '• 600000 people receive dose Pfizer/BioNTech vaccine UK',
#  'batch Pfizer vaccine COVID19 arrives Oman',
#  'reasons Stella Maris employees getting vaccine',
#  'grateful today shot @',
#  'expected COVID19 vaccine causing reactions rate superior via…',
#  'book appointment Vaccine available h…',
#  'dose yesterday',
#  'New data favour administering vaccines fast possible reserving doses v…',
#  'Working COVID vaccine clinic day today Lots happy people getting vaccinated',
#  'launched inoculation senior citizen receive BioNTech v…',
#  'available freeofcharge individuals voluntarily basis',
#  'pleased vaccine 💉 important people possible v…',
#  'offered',
#  'scheduled vaccine Putting fears aside anytime new c…',
#  'Chile’s medical personnel workers inoculated vaccine p…',
#  'WATCH: Grateful proud UAE receive jabs 🇦🇪💉…',
#  'mistyping Pfizer effect thats good news',
#  'It’s safe quickly It’s way (we let you)',
#  'Isn’t bureaucracy stopping immediate deployment ‘preparations’ right s…',
#  'Today big day vaccination started duty receive vaccine again…',
#  'Safe bodies persons',
#  'fishy',
#  'book appointment Watch gulfnews Yousra…',
#  'book appointment Vaccine available h…',
#  'book appointment Watch',
#  'Vaccination begins batches vaccine arrived…',
#  'KT Opinion: favourite celeb takes Covid jab Celebrities play huge role influencin…',
#  'countries register vaccine 🇦🇪👏👏👇👇',
#  'Positive end challenging year Amazing vaccines 2020 fantastic scientific achievement Mer…',
#  'Day post absolutely fine pain effects Covid…',
#  'data BioNTech/Pfizer Moderna Oxford/AZ significant effectiveness 1 dose…',
#  'Thank God vaccines arrived power',
#  '1 million shots vaccine given far states putting…',
#  'Vaccines fair equitable world 😍',
#  'Mohammed Frazat 88yearold Syrian second person Qatar expatriate received vaccin…',
#  'senior Emirati citizen receive PfizerBioNTech vaccine',
#  'UAE Press: vaccine rollout timely important',
#  'New York City Reports Allergic Reaction COVID19 Vaccine:',
#  'Video Explain popular benefits rental services VRS Technologies offers Apple…',
#  '70yearold Emirati Abdullah Al Barsha healt…',
#  '70yearold Abdullah Al Barsha Health…',
#  'UAE 🇦🇪 ❤️🙏🏼 expats Emiratis sons daughters great nation Mrs Lidwin Rebel…',
#  '24 hours post Covid vaccine muscle joint aches Swollen glands Felt crappy took ibuprofen feel fine',
#  'future threats thought ramp vaccinations puts downward pressure virus t…',
#  'protection protection patients family friends waiting for…',
#  'CONGRATS WESTERN WORLD❤️ U ANTI USA/WESTERNERS CRY SHAME BioNTech says produce new vac…',
#  'Finally fantastic Christmas gift vaccinated health care provider recommends it…',
#  'recipients share experience',
#  'Figure way green vaccines aluminum Ok No…',
#  'incredibly grateful scientific medical community banded vaccine development a…',
#  'Good comparison vaccines',
#  'patented happy 😀',
#  'Vaccine Update 5052 Health Impact Events 5 days administration in…',
#  'Great thread simply explaining immune system scientists researchers develo…',
#  'says vaccine arrive week flexible broken n…',
#  'Genuine question taken vaccine arm soreness effects…',
#  'Freshly vaccinated',
#  'testing new variant',
#  'Proud mass vaccination programme covid19 💉…',
#  'People focusing biceps abs photo trend receiving…',
#  'huge thank working hard Centre amazing al…',
#  'Vaccinate risk LIABILITIES amp UNTESTED💥💥💥💣💣💣 Fearmongering amp media bu…',
#  'Thats good news :)',
#  'affected country Arabian Peninsula Saudi Arabia approved USGerman vaccine…',
#  'Feeling incredibly received',
#  'vaccine Dubai gt Zabeel Primary Health Centre gt Al Mizhar Primary Health Ce…',
#  'PfizerBiontech adds 100 Million Doses Good News And…',
#  'mRNA vaccine easier adjusted based dominant variants spike protein remai…',
#  'year tough light end tunnel it’s arrived Hearte…',
#  'week receiving COVID19 vaccine hope beginning the…',
#  'vaccine sideeffect free vaccines deliver reactogenic sideeffects',
#  'week receiving COVID19 vaccine hope beginning the…',
#  'recipients share experience Happy setting precedent say…',
#  'excited got dose vaccine night I’m relieved fo…',
#  'Heres newly authorized Moderna COVID19 vaccine compares Pfizer’s 💉',
#  'code 👀👀 Look people Experimental wants guinea pi…',
#  'Pfizer supply additional 100 million doses COVID19 vaccine new agreement The…',
#  'Jorge Alcocer Secretary Health shows tracking ticket arrival batch the…',
#  'Best Christmas 🎄 gift ever: news workers 95year old grandmother’s retirement home receiving the…',
#  'approved people 18 years age older 16yo+',
#  'Stage 1 2 complete @ Brooklyn New York',
#  'EXCELLENT READ 👍👊🤜🤛',
#  'Pfizer vaccine requires second dose effective administered month first…',
#  'BREAKING: set receive additional doses new deal…',
#  'Dubai announced residents shot vaccine free starting Wednes…',
#  'Dr Marc Siegel receives COVID19 vaccine live NYU Langone hospital',
#  'Tremendous achievement parents who‘ve j…',
#  'Feeling happy parents received today thanks t…',
#  'Pfizer BioNTech reached second agreement federal government supply 100 million do…',
#  'Dubai’s starts injecting vaccine 💉 today persons receive are: Mr A…',
#  'LATEST: vaccine initially rolled people 60 frontline workers…',
#  'launches vaccination campaign Vaccines administered free cha…',
#  'Pfizer/BioNTech vaccine Covid19 shot win approval EU medicines regulator cle…',
#  'non resident non taxpayer UK to…',
#  'vaccine free eligibility criteria panned batch Pfizer shots…',
#  'plans begin free inoculation campaign Wednesday 23 December employing vaccine candidate deve…',
#  'SkyCargo transports batch vaccines Health Authority…',
#  'initially available 60s frontline workers age gr…',
#  'pay ad',
#  'Dr Abdullah Al Kubaisi director Qatar University person receive vacc…',
#  'effective vaccine 95% — healthy number World Health Organisation said i…',
#  '[Dubais free drive] second voluntary vaccine rollout country the…',
#  '[Dubais free drive] “mRNA vaccine” developed pharmaceutical company and…',
#  'mutation B117 70% contagious OMG GONNA DIE LINE VAXX SHOT BY…',
#  'latest blog post Bill Gates says “there good news coming 2021 citing stunning scientific advances…',
#  '95% effective Pfizer vaccine rolled Dubai residents starting today FREE cost😍💯…',
#  'BREAKING: Dubai begin Pfizer vaccine residents free charge TODAY',
#  'Pfizer right like',
#  'like able choose vaccine',
#  'Joe Biden receives dose Pfizer COVID19 vaccine',
#  'family friends pretty LOVE VERB',
#  'Super grateful receive COVID19 vaccination today Keeping patients safe …',
#  'Boom 💥 Right delt Grateful given opportunity \u2066 \u2066 \u2066 ✅ 1 2 💉🤗…',
#  'Great chat truths myths',
#  '444 new cases additional 12 deaths total 777 deaths linked pandemic 4108 peo…',
#  'Live updates: Pfizer Trump administration nearing deal additional vaccine doses multiple authors…',
#  'Welcoming vaccines amp today Thank who…',
#  'Happy join ranks COVID Vaccine 💉 1 ☑️ Thank',
#  'real pleasure volunteer post nights shift consent patients staff key workers a…',
#  'think clear winner Healthcare worker administering reali…',
#  'confirm felt got dose…',
#  'think sexy european',
#  'Nears Deal Provide Vaccine Doses',
#  'Yay got COVID19 vaccine UMMC feeling fine 😃',
#  'Tremendous effortsfor better mankind',
#  'clinic underway administered Kalamazoo County right now…',
#  '“We protecting high risk” BULL SHIT true 16 yo grocery workers wouldn’t…',
#  'gets ahead free drive',
#  'Italian Medicines Agency ( General Manager Nicola appears emotional announcing the…',
#  '3 hours effects noted far widely descri…',
#  'According PfizerBioNTech vaccine soon available free charge…',
#  'News alert 🚨: approved 2nd vaccine roll public free charge starting Wednesday',
#  'Dose 1 complete quotes glass enter quote…',
#  'finally light end tunnel',
#  'begin testing COVID19 vaccines new',
#  'week doses vaccine administered members of…',
#  'Massive announcement Free Pfizer vaccine vaccination drive starting tomorrow…',
#  'COVID19 vaccination: task',
#  'Covid jab likely protect new variant',
#  'Nice article explaining RNA vaccine work',
#  'sat fresh cup coffee ☕️ witness receive vaccine live lik…',
#  'vaccination started residential care centres 96 years old Jos Hermans wa…',
#  'received COVID19 vaccine feels bit exciting historic 😁',
#  'vaccinations begun administered nursing homes #',
#  'important addition vaccine wondering ho…',
#  'freezers arrive start Dec 27',
#  'Great hear North Shields Primary Care Network (PCN) Director Dr Dave Tomson speaking team effort involved…',
#  'Public outcry Stop lying 🤥 wants',
#  'Congratulations John Amazing photos North Shields second site goes live',
#  'HIGHLY DOUBT IT💯 CANT CONTROL',
#  'scared and/or worried new vaccine',
#  'Grateful amp proud COVID19 vaccine doses minimise risk patients see…',
#  'Barring economics knowledge health system externality future recommend send right signa…',
#  'set $13B 2021 vaccines able follow lucrative footsteps',
#  'Check excellent resource Vaccines amp Immunity \u2066 realtime information and…',
#  'produced experimental vaccine unsafe amp safety data…',
#  'eligible covid vaccine ensure family stay safe Here’s looking better 2…',
#  'wonderful speaking people UK received the…',
#  'EU Approves COVID19 Vaccine READ MORE:',
#  'Presidentelect ( received dose vaccine televised eve…',
#  'vaccine batch given elderly chronic conditions amp medical staff fr…',
#  'CEO says provide new mimic significant 6 weeks a…',
#  'Chief Executive said Monday confident codeveloped (with w…',
#  'Singapore Asia’s country receive delivery vaccine Monday Dece…',
#  'receives Asias shipment COVID19 Vaccine 21 Dec week prior to…',
#  'Founder biotechnology company Ugur Sahin said vaccine effective new mu…',
#  'folks I’ve dose vaccine Sunday good eff…',
#  'Interesting tendency Americans usually calling Pfizer Europeans BioNTechVaccine',
#  'began administering vaccines week ago approved jabs developed Moderna',
#  'Presidentelect publicly receives course',
#  '🚨 EU vaccine roll hundreds millions ‘careful’ regulator review…',
#  'Presidentelect received dose vaccine Monday',
#  'Sosomething pretty cool happened today',
#  'decline federal funding receive EUA 🙌🏻 PfizerBioNTech COVID19 vaccine dev…',
#  'Presidentelect received dose live television Mon…',
#  'Day3 far good',
#  'Singapore gets Asias PfizerBioNTech coronavirus vaccine doses',
#  'finally gave green light Monday paving way the…',
#  'PresidentElect Joe Biden Receives Dose PfizerBioNTech Coronavirus Vaccine',
#  'REAL news Tiffany P Dover old pics sold new ones FB account canceled today isnt…',
#  'shipment Coronavirus (Covid19) vaccine manufactured Pfizer Biontech arrived S…',
#  'Today joined thousands people receiving thanks our…',
#  'Presidentelect received course vaccine ChristianaCare Hospita…',
#  'Presidentelect Joe Biden got vaccinated live television received dose of…',
#  'nurse practitioner ChristianaCare hospital Delaware administered dose vaccine produced by…',
#  'Interesting read thoughts Polyethylene Glycol cause anaphylaxis receiving the…',
#  'far vaccine works',
#  'got vaccine today I’m feeling fine early Christmas present I’m hoping w…',
#  'Stop taking pictures giving vaccine start giving widely',
#  'want ask World Health Organization (WHO) Isnt strange find new strain evolution the…',
#  'vaccines changed 🌍 lucky seen real life older generations r…',
#  'Chinas Sinovac COVID19 vaccine proves effective Brazil trials WSJ',
#  'Covid: Presidentelect Joe Biden gets vaccine live TV',
#  'Given questions allergic reactions happy this…',
#  'December 21 2020🇨🇦 information COVID19 pandemic Canada world click li…',
#  'Presidentelect received dose vaccine Monday event br…',
#  'know ingredients genuinely involved vaccine dont want healthy young man…',
#  'dick trusts upper arm easily',
#  'shot protect family friends colleagues neighbors p…',
#  'Grandad getting vaccine tomorrow —a great scientific achiev…',
#  'Hopefully step putting Great service Vaccine team this…',
#  'Biden receives dose coronavirus vaccine publicly',
#  'Presidentelect received dose coronavirus vaccine Monday afternoon…',
#  'it’s developed Oxford amp vaccine whe…',
#  'vaccine quickly immunity kick example flu vaccine takes t…',
#  '“We owe big do” gives kudos frontline health workers including nurse practitioner…',
#  'woke right deltoid pain morning High psychosomatic resemblance IM injection Ive thinki…',
#  'Feeling fine 48 hours',
#  '3500 arrive freezers neg 20f',
#  'Thank best christmas present 65 year old nhs worker mum vaccinated today against…',
#  'authorisation Eur…',
#  'reports 4 new cases ℹ️ total 1871 individuals received dose of…',
#  '🔴 European Union approved Coronavirus vaccine inoculations start 27 co…',
#  'vaccines 95% effective based mRNA similar mild effect profile',
#  'win Lets',
#  'busy week I’ve managed social media feed need…',
#  'shipment arrived 🇸🇬 Priority given healthca…',
#  '🦠 report vaccine 💉 approval Europe new strain be…',
#  'Dr Lisa (Wahlrab) Walsh 05 receive COVID19 vaccine week Re…',
#  'vaccine protecting new UK Covid variant answer Yes according Evercore IS…',
#  'balk accepting cell line kidney Holocaust victim injustice f…',
#  'Half million people Britain received dose Covid19 vaccine',
#  'Interesting interview John Moore Professor Microbiology Immunology re: UK appro…',
#  'vaccinated disease spread easily',
#  'Proud received vaccine today comfortable wearing PPE day Grateful l…',
#  'turn return favor: spending day vaccinating employees the…',
#  'transfer shipment vaccine',
#  'COVID19: book appointment PfizerBioNTech vaccine Vaccine available h…',
#  'summer 2020 exponentially spreading declined offers procure millions addit…',
#  'grateful super excited hospital ho…',
#  'Nice comparison',
#  'responsible 2020',
#  'doses reach',
#  'Happy Boxing Day Usually day Finns meet friends movies etc Today we…',
#  'batch arrive',
#  'shipment Pfizer Covid19 vaccine reaches France Saturday Vaccination dose begins sunday…',
#  'taking delivery noon Saturday 10000 th…',
#  'Found beautiful article (thanks amazing) works try…',
#  'Irish boy writes requesting vaccination Santa receives reply CEO New Y…',
#  'Feeling normal Day 2 post',
#  'miraculous result frontiers modern Biotechnology amp information technology Entire dev…',
#  '95% effective Pfizer vaccine rolled Dubai residents starting today FREE cost😍💯…',
#  'Tony Blair makes good point shot curb pandemic',
#  'Singapore December 30 Asian country begin vaccination programme PfizerBioNTechs C…',
#  'sizes available Etsy shop',
#  'Elle snifé 😱 hey easy respire calmement 🤪',
#  'Today arrived COVID19 Vaccine Italy Thanks President Trump gi…',
#  'day received vaccine 👍🏼 arm soreness a…',
#  'light hearted fun: know took',
#  'excitement kids waiting Santa come Went sleep early woke alar…',
#  'happy day begins roll Vaccination t…',
#  '95 new 💯 👏🏻',
#  'country million people signed $ 18 million agreement for…',
#  'took delivery batch vaccine Saturday vac…',
#  '101yearold woman Germany receive PfizerBioNTech vaccine coronavirus',
#  'Super grateful received today encourage do…',
#  'COVID19: book appointment PfizerBioNTech vaccine Vaccine available h…',
#  '101yearold woman elderly care home person inoculated against…',
#  'Got vaccine 💉 early morning December 24th',
#  'trust trust Oxford seen kind moronic twa…',
#  'France administered dose vaccine total 50 people (no zeros missing) p…',
#  'check page 132 Covid19 vaccine protocol highly recommend women to…',
#  'person receive vaccine shares means',
#  'Germans huge mistake WorldEnglish',
#  'Lebanon reserving nearly 2 million doses fight cover…',
#  'best Christmas gifts I’ve received weekend protect family friends patient…',
#  '💉 received 1st dose vaccine 🌊 healthcare provider vaccinati…',
#  'constantly recieving questions useful sheet both…',
#  'got dad Incredibly lucky opportunity vulnerable member…',
#  'feels like historic victory medical science Hoping vaccine available soon around…',
#  '✅ Dose 1 vaccine complete',
#  'happy mother getting yesterday Thank ☺️☺️',
#  'Health professionals elderly vaccinated country coming weeks…',
#  'Pfizer CEO Albert Bourla coronavirus vaccine developed company BioNTech sa…',
#  'Spains health minister said country facing delay fresh delivery vacc…',
#  'cool things didn’t know vaccine 👀 read article here…',
#  'vaccine prevent deaths given patients admitted hospital so…',
#  'dose ✅',
#  'moves fast medics 2270 medical workers vaccinated 1st daySunday Thnx hard…',
#  'Hatred ask said true Buhari southerner death the…',
#  'Bhd ready efficiently distribute expected ready…',
#  'Incredibly grateful scientists developed COVID19 vaccines giants shoulders stoo…',
#  'received dose Covid19 vaccine',
#  'non molecular biologist geeks good detailed analysis mRNA f…',
#  'dose covid19 vaccine',
#  'Couldn’t agree — Joydeep',
#  'Lebanon vaccines February',
#  'vaccination started Berlin Brandenburg Hopefully better 2021',
#  'latest coronavirus pandemic vaccines',
#  'Im grateful healthcare workers globe keeping healthy safe…',
#  'Dont think Think accepting stringency exact 21d booster P…',
#  'PMs Spokesman said UK recd 25 Dec 22 new deliveries he…',
#  'welcome flexibility recommended 21 day interval two…',
#  'India providing emergency approval vacc administered cou…',
#  'frontline worker COVID19 blood samples today received shot COVID19 vaccine (PfizerBioNTech)…',
#  'Sideeffects tests results Looks promising encouraging with…',
#  'Ok round good anticovid19 science juice 19th second Thanks',
#  'historic moment Annie Lynch Liberties Dublin person Republic Ir…',
#  'real fear hand use o…',
#  'didn’t happen post right Grateful world…',
#  'right 1methyl3pseudouridinemRNA aft…',
#  '79yearold patient named Annie Liberties receive vaccine Republic Ir…',
#  'grateful vaccine COVID 4 weeks ago i…',
#  'news jab recipient Margaret Keenans second injection weeks jab 8th December',
#  'like there’s light end tunnel',
#  'remember correctly vaccine developed Turks opts sellout the…',
#  'Adding took Xmas week fe…',
#  'vaccination bag night 💉',
#  'live Dubai want Covid vaccination read this:',
#  'Moderna Vaccine Safe Allergic Reactions Effects',
#  'doctor TRULY BELIEVES work tests',
#  'DEATH VOLUNTARY LETHAL INJECTION THANKS',
#  'think crop dusters good startegywonder Pharma happen',
#  'Brilliant news vaccine approved ne…',
#  'Nurse tests positive despite receiving means to…',
#  'Nurse tests positive despite receiving',
#  'excited today delay week cuz service couldnt pr…',
#  'Vaccinated nurse contracts COVID19 expert says Pfizer shot needed time work ABC nurse Californ…',
#  'nurse I’m excited thankful received partwear…',
#  'Chairman Supreme Committee Crisis Disaster Management receives dose…',
#  'Apart great news Oxford Astra Zeneca vaccine approved update Al…',
#  'doses European Union buy summer Pasteur Institute money Pr Fo…',
#  'scientific evidence vaccine effective 12 weeks apart G…',
#  'great news refrigerated 6 months doesnt c…',
#  '| 45yearold nurse Matthew W tested positive week receiving…',
#  'standard rules doses drawn vial experts said right needle and…',
#  'Happy New Year science best 21 days',
#  'Day 1 post COVID19 shot: arm sore (very mild) running errands usual',
#  'informed debate question things things worried…',
#  'Dearest American Friends IGNORE RESTRICTIONS SOCIAL DISTANCING GODS SAKE: WEAR MASK…',
#  'Official statement use vaccine history anaphylaxis good new…',
#  '💉 approval American regulator happen sha…',
#  'cover entire population combined order jab Health Secretary Matt Hancock said',
#  '[ | vaccine cheaper developed companies be…',
#  'V day today day hope feels start good encourage believe science…',
#  'remember twitting lady taking covid vaccine live TV twitter remove timeline…',
#  'countries begun phase vaccination drive vaccinated 2…',
#  'AstraZeneca easy distribute home fridge a…',
#  'wheres list ingredients allergic Commercially sensitive li…',
#  'dose think gives 50% need second dose 95% Ramers a…',
#  'dose ✅😃',
#  'successful trial like weve seen all…',
#  'believe contribution development vaccine let’s start calling it…',
#  'UK 🇬🇧 happy helping volunteering pr…',
#  'join magnificent vaccination team late shift also…',
#  'Gratitude entry 1 1 Receiving dose Pfizer vaccine holidaying soon importantly needing…',
#  'safe we’re safe… peer peer vaccinator team pharmacy team ready rol…',
#  'India providing emergency approval vacc administered cou…',
#  'Great news vaccine getting UK approval Huge development nationally internationall…',
#  'Agree comments irresponsible article key point ‘immunity’ can…',
#  'ordered million doses USGerman vaccine delivery of…',
#  'According Dr Christian Ramers infectious disease specialist case Matthew surprising but…',
#  'nurse received emergency Pfizer shot tests positive',
#  'dose',
#  'married folks Malice Verbal Malice crossover Food Malice Sexual Malice Fin…',
#  'good news total confidence vaccine adding arsenal against…',
#  'countries begin inoculation today 46yearold nurse in…',
#  'New strain: 20 returnees test positive new variant',
#  'Margaret Keenan Worlds Patient PfizerBioNTech COVID19 Vaccine Receives Second Jab:…',
#  'December 2 vaccine goahead use West Britai…',
#  'Asian country start vaccinating healthcare workers with…',
#  'Received 1st Dose Covid19 Vaccine Canada God good Time…',
#  'Nurse tested positive COVID19 week receiving Pfizer vaccine Remember the…',
#  'Free Vaccine day QE Hospital Birmingham Turn Queue',
#  'Mr President elect saw people received applied receive it…',
#  'years worth anxiety fear bubbled face today',
#  '4 elderly people died announced record 907 new cases suggesting government…',
#  'Europe ready buy extra 100 million doses vaccine',
#  '70 total doses administered France 20 yesterday epidemiologist actuall…',
#  'VACCINE',
#  'got vaccine jab second 19 days it’s amazingl…',
#  'Max Names Max Thats Better Turn Looking Bob',
#  'Daily Mail saying GP’s aren’t happy cancelling second dose appointments 80’s Claiming ‘breach of…',
#  '24hrs dose 1 feeling great little sore actually way expecting symptom…',
#  'Happy New Year folks',
#  'Ive spent evening supervising hospitals COVID19 vaccine clinic dose too…',
#  'Spent yesterday morning Erskine Hall Care Home Northwood Great organisation management team L…',
#  'Thanks Simon Useful flagged second dose bastards',
#  'ready',
#  'Best understanding description vaccine developed (including understandi…',
#  'Obligatory post tweet cant believe got dose vaccine today in…',
#  'proud humbled received dose today great experience…',
#  'Proudly vaccinated Thanks making organized amp painless experience',
#  'whilst agree notion delaying second dose vaccine allows doses given am…',
#  'Here’s better tomorrow',
#  'Imagine given huge time rebook appo…',
#  'New Year 2021 🐌 💉 💊 🧬 🧪 🔬…',
#  'colleagues started 5000 vaccines on…',
#  'true 😅',
#  'Exactly Talk clutching defeat jaws victory',
#  'taken mom dose vaccine 👍🏻💉 thanks scientists healthcare worker…',
#  'Absolutely agree Govt publish justification changing from…',
#  'main differences',
#  'Proud day 92 year old Nan dose vaccine Louth Hosp…',
#  'OkWOW major right quest good',
#  'Phenomenal idea James applaud u fact Scotl…',
#  'Today good day Thank thank thank NHS PfizerBioNTech vaccine pain a…',
#  'Good Everybody completely free chose great vaccines: th…',
#  'hope u fun tehn wiht dat hvea',
#  'thinking absolute madness glimmer hope looks like government…',
#  'COVID19 vaccine 💉✔️ Thank organised professional service delivery massive cruc…',
#  'Interesting 417% people voted said vaccine informa…',
#  'Dubai Health Authority DirectorGeneral Humaid Al Qutami received dose Covid…',
#  'faith tried thoroughly tested vaccines far C…',
#  'Results Phase 3 trial 43000 volunteers 16 years old multicountry 95%…',
#  'Grandad 89 he’s sayings favourites apt today: 1 haste speed 2…',
#  'March could’ve imagined day come end year Science knew loved you…',
#  'Pfizer vaccine gave headache turned migraine developed blown flu symptoms…',
#  'Today I’ve got best present New Year’s Eve huge thanks possible…',
#  'fortunate received dose day spent vaccinating local hub Wo…',
#  'light end tunnel way through”',
#  'right',
#  '📌 Grand Rounds Friday Jan 8 Dr share overview of…',
#  'clear message supports science',
#  'Fully vaccinated Covid 19 best gift 2021 thanks helped amp test vaccine offere…',
#  'Vaccine supply good offered distribution infrastructure need government jo…',
#  'Delighted receive vaccine today huge heartfelt thank amaz…',
#  'Great collaboration amp initial roll receiving vacci…',
#  'Good decision happy Pfizer got involved wouldn’t trust “Experts “ country Every…',
#  'American Media attempt create doubt amp discredit potential cheap competetior Briti…',
#  'day 2020 administered clinic skilled nursing facility got dos…',
#  'great way kick 2021',
#  'stored higher convenient temperature curious it’s demand…',
#  'folks green light usage vacci…',
#  'Basically lot old people vaccine trial contrary ow…',
#  '🎊🎆 better start ask ❤️ 😇 🙏🏻 💉…',
#  'friend come retirement administer reports senior manager spent of…',
#  'Covid vaccination status taught far: “Execution” eats “Science Discovery” lunch i…',
#  '😲 dose Second dose March 20th ☺️👍',
#  'mum dad doctors got dose vaccine today A…',
#  'team experts led allergists Massachusetts General Hospital (MGH) assured people with…',
#  'Let remind countries hosted vaccine trials Pharmaceutical big sho…',
#  'Happy New Year Ive lovely day vaccinating staff Care home staff',
#  'lies tell btw Pfizer vaccine developed German Comp…',
#  '1st dose lucky opportunity Thanks vaccination teams painles…',
#  'shall better wait vaccine availability India rushing shot…',
#  'delayed booster useful thread c/o',
#  'use batch 300000 Monday second ident…',
#  'Thanks ♥️',
#  'Delaying second dose reasonable vaccine so…',
#  'vaccine second dose given 21 days research evidence delaying to…',
#  'December 28th Feeling great',
#  'prefer trust seeing developed based trials…',
#  'Pfizer: data single dose vaccine offers protection 21 days',
#  'safe trust effectivity India COVID19 vaccines manner hurrying the…',
#  'can’t vaccinate properly ethically right kinds wrong…',
#  'needs stored 60°C 90°C making challenging deployed…',
#  'Emergency Use Listing (EUL) allowed countries paceup regulatory approval processes im…',
#  'deployed vaccine recently available free citizens r…',
#  'half million doses arrived authorities li…',
#  'block nod emergency use Enables amp health org…',
#  'EU countries given EUA millions inoculated with…',
#  'vaccine receive emergency validation (novel coronavirus) outbreak beg…',
#  'Pfizer/BioNTech vaccine Covid19 vaccine receive emergency use validation World Healt…',
#  'Welcome',
#  'WHOs gift New Year clears PfizerBioNTech COVID vaccine emergency use ▪️The Covid19 vacc…',
#  'Here’s great article: producers consider removing motif reduce…',
#  'Morning Brief | Pfizer gets approval Indias mysterious monolith amp guess Gal Gadots wo…',
#  '2021 begins good note Pfizer COVID vaccine approved gives green…',
#  'lists PfizerBioNTech’s COVID19 vaccine emergency use UN said aims vaccine readily…',
#  'lists PfizerBioNTech’s COVID19 vaccine emergency use UN said aims vaccine readily…',
#  'vaccine emergency validation Read more:',
#  'symptom experiencing right complete utter relief year rough everybody bo…',
#  'opens way regulators worldwide quickly approve import distribution',
#  'dose vaccine received light end tunnel',
#  '💉✅⛔️To vax vax ☪️Check latest article published PfizerBioNTech vacc…',
#  'Got COVID 19 vaccine Cheers scientists faced rejections believed novel concept mRNA…',
#  'second vaccine today thanks lovely GP surgery colleagues ✅💉',
#  'Discussions surrounding change single dose versus scheduled double dose Main players market for…',
#  '5MHRA guidelines GPs: 1 person history significant allergic reaction vaccine medicine o…',
#  'Returning COVID Unit Hamilton General middle wave 2 powered the…',
#  '(1/3) COVID19 Vaccines beginning roll raised people able privately…',
#  'Welcoming 2021 exciting manner Happy vaccination day (part 1) Grateful be…',
#  'Oh happy day 🥰',
#  'AstraZeneca vaccine effective USs Government ordered insu…',
#  'Worlds 2nd populous nation sight amp sound Covid19 vaccine promising success…',
#  'million people Israel received doses vaccine',
#  'Maj Gen Mohammed Al Marri Director General General Directorate Residency amp Foreigners Affairs (GDRFA)…',
#  'said plenty vaccines available week',
#  'Mild arm soreness 24 hours fatigue 48 hours mild backache 24 hours Peachy',
#  'Seeing haters attack cry social media Israeli achievement success brings joy…',
#  'Thanks fabulous got jabbed today 💪',
#  'Got dose Vaccine Incredibly grateful scientist colleagues urge y…',
#  'check understand question marks remain abou…',
#  'Covid19 Vaccines Available Americans Interested Getting Vaccinated',
#  'Sitting hospital waiting Covid 19 vaccine IM READY',
#  'useful statement 👌🏾 summary patients the…',
#  'Head Head: Covishield V/S PfizerBioNTech Better COVID19 Vaccine Right',
#  'approved PfizerBioNTech vaccine Read',
#  'Hill December 29 2020 patient receive COVID19 vaccine gets second shot',
#  'Hill December 29 2020 patient receive COVID19 vaccine gets second shot',
#  'World Health Organization granted emergency use validation',
#  '1400 individuals vaccinated far – report',
#  'Hands thought vaccines free online publisher owned EBay h…',
#  'favorite',
#  'Dubai Health Authority revealed list different categories individuals wont able rece…',
#  'vs vs vs vaccines compare…',
#  'vaccine *Scientists warn directly comparing efficacy vaccines eac…',
#  'Dr Marc Siegel: COVID vaccinations increase rapidly — greatest accomplishment vaccine history | Fox News \u2066…',
#  'ANYBODY believe real know family wiped th…',
#  'Vaccinated Got dose',
#  'Astounding scenes film Pfizer Vaccine incredibly effective takes 2 pharmacists 10 min…',
#  'deliveries vaccine continue weekly basis order 200 million expe…',
#  'Thank offering Children’s Social Care staff vaccination wee…',
#  'truly emotional moment looks simple little jab heart gratitude scientist…',
#  'YES LIMITING FACTOR BREAK 2021 GRADUALLY GETTING BETTER 202…',
#  'Best way start week new year 😷💪🏻🙏🏻 2🦠2💉',
#  'warned evidence jointly developed continue protect aga…',
#  'Happy received 1st covid vaccine afternoon great start 2021 th…',
#  'Data Demonstrate Protection Covid19 Vaccine Sustained 21 Days Dose…',
#  'vaccine administered people UK today second vacci…',
#  'people Ontario getting second dose vaccine course it’s great p…',
#  'thankful received dose vaccine',
#  'Thanks Team I’ve 1st vac…',
#  'Iran records 6073 daily confirmed cases COVID19',
#  'Covid19 Vaccines Available Americans Interested Getting Vaccinated',
#  'OK heres main worry Covid vaccine sticker brave boy',
#  'Starting 2021 positive note: run 10k play tennis daily kids preparing fortunate grateful ar…',
#  'lt1k (concentrating old vaccinate gt1M end Jan) 240k (they alre…',
#  'family loved ones future patients Great start new year',
#  'PM blaming manufacturers vaccines UK able vaccinate millions o…',
#  'wondered works mechanism action differs',
#  'Iran records 6073 daily confirmed cases COVID19',
#  'Major General Talal Belhoul Al Falasi DirectorGeneral State Security Department Dubai receives 1st sho…',
#  'December 23 2020 total 1893360 doses PfizerBioNTech COVID19 vaccine administered…',
#  'Pfizer vaccine approved countries mass inoculation',
#  'Thanks read paper data HIVpositive patients b…',
#  'proud involved preparation ( vaccine today…',
#  'Update: Im 24 hours post 2nd dose amp Ive experienced effects interesting Iv…',
#  'Got dose COVID19 vaccine Thanks science/medicine thanks Pfizer conspiracy theories…',
#  'interesting data number age group',
#  'Bloomberg: EU Seeks 300 Million PfizerBioNTech Doses',
#  'dont worry Germany gets 186% vaccines EU ordered single dose…',
#  'Thankful Covid vaccine today impressed organisation efficiency vaccination te…',
#  'gets numbers wrong document concerning causing lot confus…',
#  'supplies vaccine ready',
#  'deceaseds father Abilo Acevedo told Portugese daily Correio da Manha: okay hadnt health…',
#  ...]

# %%
# Tokenization
for line in positive_tweet_list:
#     print(line)
    for token in line.split():
        print(token)
# Out:
# Streaming output truncated to the last 5000 lines.
# definitely
# recommend
# looking
# local
# walk
# centres
# near
# you’re
# waiting
# for…
# KT
# Shorts
# |
# vaccinate
# children
# aged
# 12
# years
# older
# Children
# given
# the…
# shares
# untreatable
# according
# powerful
# government
# heads
# board
# period
# need
# ignorance
# confidence
# SUCCESS
# sure
# follow
# 💞
# FULLY
# VACCINATED
# 💉😇💪🏻…
# eightweek
# gap
# second
# dose
# PfizerBioNTech
# Covid
# vaccine
# help
# tackle
# delta
# var…
# Enjoy
# Im
# vaccinated
# second
# time
# Double
# Pfizer
# vaxxed
# agent
# Im
# available
# mixed
# vaccination
# COVID19
# shot
# boosted
# neutralizing
# antibody
# levels
# by…
# Got
# jab
# yesterday
# Got
# jab
# arm
# sore
# glad
# 🌻
# Thanks
# 🇨🇿
# government
# agreeing
# borrow
# 1
# mil
# Pfizer
# vaccines
# 3rd
# 4th
# quarter
# 2021
# Th…
# Score
# Mix
# match
# plus
# gives
# equal
# better
# protection
# 2x
# Ar…
# shows
# strong
# protection
# severe
# disease
# lower
# effectiveness
# infect…
# study
# found
# longer
# gap
# vaccine
# doses
# led
# higher
# proportion
# helper…
# vaccine
# today
# sure
# ya
# Monday
# afternoon
# wait
# got
# 2nd
# dose
# Pfizer
# Happy
# Day
# ❤💉❤
# Second
# Pfizer
# dose
# administered
# Hope
# doesnt
# hard
# like
# know
# town
# Happy
# say…
# highness
# Emirates
# fly
# C…
# Hey
# thanks
# sharing
# thread
# Read
# version
# here:…
# TLDR
# **
# Pending
# Peer
# Review
# **
# Increased
# protection:
# 18
# 55
# Greater
# 5fold
# increase
# 65
# 85
# Gre…
# dont
# worry
# government
# cares
# wants
# best
# health😉
# Pfizer
# data
# suggest
# dose
# Covid19
# vaccine
# strongly
# b…
# Happy
# Faces😀at
# Mallow
# Vaccination
# Centre
# 18
# age
# group
# dose
# ❓How
# 2️⃣
# doses
# protect
# symptomatic
# infection
# According
# late…
# Dear
# contemplated
# acquiring
# kindly
# thoroughly
# read
# co…
# I’m
# Thursday
# 2nd
# 3
# half
# weeks
# Got
# second
# jab
# vaccinated
# haven’t
# :)
# Read
# DailyRounds
# app
# Download
# now:
# shorter
# recommended
# dose
# gap
# Year
# 12
# pretty
# fast
# وتفيزرنا
# dose
# 5
# months
# second
# dose
# feeling
# great
# 💉💪
# Mission
# Complete
# Fully
# vaccinated
# today
# ❤️
# remake
# selfie
# nung
# dose
# hehe
# sana
# po
# smooth
# like
# nung
# 1st
# dose
# 😇…
# obvious
# world
# spacing
# vaccine
# needs
# to…
# COVID19
# Vaccine
# second
# dose
# completel
# (Alhamdolillah)
# 💗💗💗
# Stay
# Home
# Stay
# Safe
# Data
# far
# positive
# mix
# match
# vaccines
# consider
# decisi…
# 3rd
# vax
# dose
# strongly
# boosts
# protection
# variant:
# Read
# at…
# Currently
# getting
# ready
# jabbed
# booster
# vaccine
# trial
# me…
# 2
# contemporary
# SUPER
# Premiums
# sale
# best
# offer
# basis…
# arm
# sorer
# flu
# shot
# thought
# got
# placebo
# Pretty
# impressed
# way
# handles
# vaccination
# process
# digitalization
# Covidpass
# ready
# on…
# eightweek
# gap
# second
# dose
# PfizerBioNTech
# Covid
# vaccine
# help
# tackle
# delta
# var…
# Interesting
# coverage
# Delta
# variant
# threat
# scientists
# know
# genetic
# code
# o…
# Good
# stuff
# patriot
# wanted
# jab
# was…
# Ct
# value
# similar
# fully
# vaxd
# (127)
# vs
# (84)
# (227
# vs
# 215)
# cases
# males
# (85%)
# median
# age
# 40…
# Israel
# roll
# booster
# dose
# COVID19
# vaccine
# older
# people
# citing
# drop
# prote…
# got
# (
# dose
# (
# second
# dos…
# Today
# good
# day💉💉🙌🙌
# Thank
# Patients
# developed
# conditions
# receiving
# similar
# rate…
# announced
# nearly
# 10%
# 121…
# calls
# rare
# cases
# caused
# far
# US…
# lets
# break
# down:
# according
# perfectly
# acceptable
# 93%
# 89
# million
# adolescent…
# version:
# today
# announced
# perfectly
# satisfied
# w/t…
# remarkable
# number
# anonymous
# accounts
# continue
# push
# unfounded
# claim
# the…
# Saudi
# reopen
# borders
# international
# tourists
# August
# 1
# Read
# More:
# efficient
# quick
# like
# station
# thats
# moving
# Sophie
# aged
# 18
# excited
# opening
# Walk
# vaccination
# clinic
# Killarney
# Sports
# amp
# Leisure
# centre
# today
# 11am
# to…
# decision
# year
# 12
# good
# addresses
# hesitancy
# ar…
# vaccine…
# 1/2
# Expect
# Youre
# Expecting
# child
# 511
# years
# old
# eligible
# 1st
# shot
# 💉💉💉
# Good
# job
# brave
# 🤩🤩🤩
# @
# Quezon
# City…
# dose
# cutie
# patootie
# report:
# 👇👇👇
# Health
# Canada
# approves
# COVID19
# vaccine
# children
# Canada
# received
# doses
# covid
# 19
# vaccine
# 511
# aged
# childrens
# Right
# getting
# 3rd
# Jab
# Pfizer
# Vaccine
# Children
# 511
# Age
# Group
# Approved
# Read
# story
# here:…
# data
# realease
# safety/efficacy
# data
# ye…
# vaccine
# modern
# like
# iPhone
# pro
# antivax
# crowd
# suspicious
# it’s
# rota…
# 10000
# Australians
# applied
# com…
# Health
# Canada
# authorized
# COVID19
# vaccine
# children
# ages
# PfizerBioNTechs
# two…
# latest
# country
# authorise
# children
# aged
# be…
# Protect
# self
# protect
# loved
# ones
# protect
# Ive
# accomplished
# social
# obligations
# responsi…
# wants
# vax
# know
# Thanks
# marvelous
# boosted
# Schoolaged
# children
# likely
# test
# positive
# children
# received
# single
# dose
# of…
# ~10%
# children
# aged
# 511
# got
# shot
# week
# 17M
# vaccinated
# 28M
# young
# children
# gr…
# fully
# vaccinated
# 💯💉🦠
# Thank
# Magsingal
# Health
# Office
# 💙
# turn
# responsible
# VACCIN…
# Yes
# Children
# ages
# 5–11
# years
# receive
# onethird
# adult
# dose
# vaccine
# tha…
# booster
# time
# tim…
# dose
# ✅

# %%
pos_tokens = [token for line in positive_tweet_list  for token in line.split()]
neg_tokens = [token for line in negative_tweet_list  for token in line.split()]
neut_tokens = [token for line in neutral_tweet_list  for token in line.split()]

# %%
pos_tokens
# Out:
# ['useful',
#  'advice/guidance',
#  'COVID',
#  'vaccine',
#  'safe',
#  'whilst',
#  'breastfeeding…',
#  'bright',
#  'days',
#  '2020',
#  'best',
#  '1',
#  'winning',
#  'deaths',
#  'closing',
#  '300000',
#  'mark',
#  'millions',
#  'people',
#  'wait',
#  'U…',
#  'Best',
#  'wishes',
#  'US…',
#  'agency',
#  'released',
#  'new',
#  'information',
#  'health',
#  'care',
#  'providers',
#  'patients',
#  'shipped',
#  'millions',
#  'd…',
#  'Trump',
#  'announces',
#  'rollout',
#  '24',
#  'hours',
#  'Americans',
#  'vaccinated',
#  'against…',
#  'Coronavirus:',
#  'Iran',
#  'reports',
#  '8201',
#  'new',
#  'cases',
#  '221',
#  'deaths',
#  '24',
#  'hours',
#  'paid',
#  'approve',
#  'sudden',
#  'money',
#  'makes',
#  'world',
#  'Trump',
#  'announces',
#  'rollout',
#  '24',
#  'hours',
#  'Americans',
#  'vaccinated',
#  'against…',
#  'Presenting',
#  'Medical',
#  'News/Advancement',
#  'past',
#  'week',
#  'dont',
#  'want',
#  'miss',
#  'Interesting',
#  'detailed',
#  'article',
#  'showing',
#  'tested',
#  'help',
#  'd…',
#  '6',
#  'deaths',
#  'far',
#  'death',
#  'worry',
#  '🤔',
#  'Trump',
#  'announces',
#  'rollout',
#  '24',
#  'hours',
#  'Americans',
#  'vaccinated',
#  'against…',
#  'I’ve',
#  'excited',
#  'vaccine',
#  '💉💉💉',
#  'Building',
#  'week’s',
#  '‘trial’',
#  'run',
#  'extending',
#  'vaccination',
#  '💉',
#  'programme',
#  'week',
#  'effort',
#  'going',
#  'b…',
#  'COVID19',
#  'vaccine',
#  'doses',
#  'arrived',
#  'Oregon',
#  'Watch',
#  '6am',
#  '9am',
#  'tomorrow',
#  'det…',
#  'great',
#  'feeling',
#  'big',
#  'thank',
#  'healthcare',
#  'professionals',
#  'scientists',
#  'nurses',
#  'doctors',
#  'caregivers…',
#  'Members',
#  'delivered',
#  'morning',
#  'Getting',
#  'dose',
#  'weekend',
#  'seeing',
#  'r…',
#  'taking',
#  'COVID19',
#  'vaccine',
#  'available',
#  'New',
#  'York',
#  'state',
#  'administered',
#  'nontrial',
#  'vaccine',
#  'morning',
#  'health',
#  'care',
#  'worker',
#  'P…',
#  'ICU',
#  'nurse',
#  'Sandra',
#  'Lindsay',
#  'said',
#  'proud',
#  'Americans',
#  'receive',
#  'Pfizer…',
#  'Odd',
#  'verb',
#  'choice',
#  'Doug',
#  'hand',
#  'observe',
#  'welcome',
#  'Anita',
#  'Anand',
#  'under…',
#  'Ontarian',
#  'vaccinated',
#  'minutes',
#  'later',
#  'PSW',
#  'Anita',
#  'Quidangen',
#  'Toronto',
#  'weekend',
#  'issued',
#  'guidance',
#  'pilots',
#  'following',
#  'use',
#  'new',
#  'for…',
#  'Surprised',
#  'learn',
#  'autoimmune',
#  'conditions',
#  'immunosuppressed',
#  'advised',
#  'receive',
#  'the…',
#  'Vaccine',
#  'Works',
#  'article',
#  'detailed',
#  'explanation👇',
#  'new',
#  'type',
#  'vaccine',
#  'man',
#  'daft',
#  'hurts',
#  'ears',
#  'listening',
#  'biggest',
#  'question…',
#  'COVID19',
#  'VACCINATIONS',
#  'TODAY',
#  '🙌🏻',
#  'Thank',
#  'stepping',
#  'getting',
#  'personal',
#  'support',
#  'worker',
#  'people',
#  'receive',
#  'a…',
#  'Legacy',
#  'Health',
#  'registered',
#  'COVID19',
#  'vaccine…',
#  'KFDM’s/FOX',
#  '4’s',
#  'Baptist',
#  'hospital',
#  'getting',
#  'hand',
#  'look',
#  'Pfizer',
#  'COVID19',
#  'vacci…',
#  'Canadian',
#  'PM',
#  'Justin',
#  'Trudeau',
#  'announced',
#  'arrival',
#  'vaccine',
#  'vials',
#  'country',
#  'vaccines',
#  'receivers',
#  'Momentous',
#  'science',
#  'Hope',
#  'arrived',
#  'good',
#  'news:',
#  'doses',
#  'vaccine',
#  'arrived',
#  'California',
#  'night',
#  'Gov',
#  'Gav…',
#  'Supervising',
#  'I’m',
#  'torn',
#  'politicians',
#  'going',
#  'first(ish)',
#  'important',
#  'is…',
#  'night',
#  'arrived',
#  'Canada',
#  'speak',
#  'vaccines',
#  'admin…',
#  'Happy',
#  'Cold',
#  'Chain',
#  'Day',
#  'way',
#  'vaccine',
#  'distributed',
#  'county',
#  'Received',
#  'dose',
#  'today',
#  'feel',
#  'privileged',
#  'amp',
#  'lucky',
#  'p…',
#  'hospital',
#  'work',
#  'received',
#  'vaccine',
#  'IV',
#  'room',
#  'doses',
#  'given',
#  'state',
#  'I’…',
#  'night',
#  'welcomed',
#  '30K',
#  'doses',
#  '🇨🇦',
#  'l…',
#  'nurse',
#  'New',
#  'York',
#  'City',
#  'Monday',
#  'person',
#  'United',
#  'States',
#  'receive',
#  'corona…',
#  'nurse',
#  'New',
#  'York',
#  'City',
#  'Monday',
#  'person',
#  'United',
#  'States',
#  'receive',
#  'coronavirus…',
#  'received',
#  'shipment',
#  'vaccine',
#  'line',
#  'healthcare…',
#  'It’s',
#  'kind',
#  'surreal',
#  'vaccine',
#  'dropping',
#  'today',
#  'President',
#  'Trump',
#  'says',
#  'vaccine',
#  'United',
#  'States',
#  'administered',
#  'Vaccination',
#  'campaign',
#  'begins',
#  'today',
#  'Quebec',
#  'Residents',
#  'Maimonides',
#  'seniors',
#  'in…',
#  'Kudos',
#  'UPS',
#  'announced',
#  '13th',
#  'involvement',
#  'amp',
#  'support',
#  'distribution',
#  'efforts',
#  'Tuna',
#  'Container',
#  'Freezers',
#  'Ship',
#  'Given',
#  'New',
#  'Role',
#  '…',
#  'end',
#  'sight',
#  'coworkers',
#  'getting',
#  'doses',
#  'to…',
#  'Sunday',
#  'evening’s',
#  'shipment',
#  'initial',
#  '30000',
#  'doses',
#  'Pfizer',
#  'vaccine',
#  'spread',
#  '14',
#  'dist…',
#  'Approves',
#  'Pfizer',
#  'Vaccine',
#  'Shipment',
#  'Expected',
#  'End',
#  'Says',
#  'PM',
#  'Lee',
#  'Hsien',
#  'Loong…',
#  'approvals',
#  'vaccine:',
#  'approves',
#  'expects',
#  'shots',
#  'Decemb…',
#  'Pfizer',
#  'coronavirus',
#  'vaccine',
#  'doses',
#  'set',
#  'arrive',
#  'hospitals',
#  'vaccinated',
#  '11',
#  'million',
#  'new',
#  'cases',
#  'confirmed',
#  'past',
#  'week',
#  'death',
#  'toll',
#  '30600…',
#  'Oh',
#  'great',
#  'thought',
#  'wouldnt',
#  'able',
#  'Xmas',
#  'btw',
#  'heard',
#  'radio',
#  'Shropsh…',
#  'Monday',
#  'Asian',
#  'country',
#  'approve',
#  'said',
#  'ex…',
#  'Singapore',
#  'approves',
#  'Pfizer',
#  'vaccine',
#  'south',
#  'East',
#  'Asian',
#  'country',
#  'approve',
#  'vaccine',
#  'Doses',
#  'gi…',
#  'Excited',
#  'tomorrow',
#  'honoured',
#  'exciting',
#  'team',
#  'administering',
#  'primary',
#  'care',
#  'approves',
#  'shipment',
#  'expected',
#  'endDecember',
#  'Singapores',
#  'plan',
#  'tackle',
#  'effective',
#  'Early',
#  'pandemicmore',
#  '$1',
#  'bn',
#  'set',
#  'aside',
#  'fo…',
#  'Singapore',
#  'approves',
#  'vaccine',
#  'local',
#  'use',
#  'Vaccine',
#  'safe',
#  'use',
#  'people',
#  'aged',
#  '16',
#  'above…',
#  'Phase',
#  '3',
#  'begins',
#  'Dec',
#  '28',
#  'vaccine',
#  'arrive',
#  'end',
#  'Dec',
#  'shots',
#  'free',
#  'a…',
#  'True',
#  'question',
#  'vaccines',
#  'vaccine',
#  'needs',
#  'given',
#  '2',
#  'shots:',
#  'a…',
#  'million',
#  'arrived',
#  'lastminute',
#  'I’m',
#  'vaccine',
#  'Tuesday',
#  'super',
#  'thrilled',
#  'start',
#  'today',
#  'according',
#  'latest',
#  'figures',
#  'maximum',
#  'cases',
#  '(over',
#  '167',
#  'mil…',
#  'batch',
#  'doses',
#  'PfizerBioNTech’s',
#  'COVID19',
#  'vaccine',
#  'arrived',
#  'Canada”',
#  'PM',
#  'Trudeau',
#  'said',
#  'Twitter…',
#  'start',
#  'today',
#  'according',
#  'latest',
#  'figures',
#  'maximum',
#  'cases',
#  '(over',
#  '167',
#  'mil…',
#  'Good',
#  'news',
#  'vaccines',
#  'arrived',
#  'vaccines',
#  'like',
#  'coming',
#  'money',
#  'Mr',
#  'Mark',
#  'Twain',
#  'getting',
#  'doses',
#  'United',
#  'States',
#  'Interesting',
#  'approach',
#  '🇺🇲',
#  '🇬🇧',
#  'guidance',
#  'v',
#  'clear',
#  'now:',
#  'person',
#  'history',
#  'anaph…',
#  'PfizerBioNTech',
#  'COVID19',
#  'Vaccine:',
#  'Donald',
#  'Trump',
#  'Mike',
#  'Pence',
#  'amp',
#  'Officials',
#  'Offered',
#  'Early',
#  'Access',
#  'Newly',
#  'A…',
#  'safe',
#  'thank',
#  '👍',
#  'near',
#  '2030',
#  'Premature',
#  'innoculation',
#  '😇',
#  '🙏',
#  'batch',
#  'doses',
#  'vaccines',
#  'YAY',
#  'congratulations',
#  '🙏…',
#  'information',
#  'vaccine',
#  'severe',
#  'allergies:',
#  'Welp',
#  'thanks',
#  'arent',
#  'going',
#  'planned',
#  'distribution',
#  'aren…',
#  'excellent',
#  'news',
#  'great',
#  'President',
#  'Trump',
#  'administration',
#  'pushed',
#  'vaccine',
#  'ready',
#  'qui…',
#  'process',
#  'definitely',
#  'thought',
#  'publicity',
#  'wise',
#  'case',
#  'interested',
#  'link',
#  'patient',
#  'information',
#  't…',
#  'vaccines',
#  'going',
#  'officially',
#  'allows',
#  'COVIDvaccine',
#  'given',
#  'green',
#  'light',
#  'kind',
#  'leave',
#  'Grateful',
#  'group',
#  'vaccinated',
#  'healthcare',
#  'workers',
#  'Tampa/FL',
#  '🙏🏽…',
#  'Dr',
#  'Kathy',
#  'Lofy',
#  'says',
#  'vaccine',
#  'new',
#  'tool',
#  'tool',
#  'box',
#  'says',
#  'she’ll',
#  'vaccinated',
#  'soon',
#  'as…',
#  'recommended',
#  'use',
#  'vaccine',
#  'persons',
#  '16',
#  'years',
#  'age',
#  'older',
#  'the…',
#  'Boxes',
#  'containing',
#  'shipment',
#  'PfizerBioNTech',
#  'prepared',
#  'sent',
#  'great',
#  'day',
#  'Country',
#  'amp',
#  'World',
#  'DAY',
#  'CLOSER',
#  'leaving',
#  'first…',
#  'watched',
#  'new',
#  'correctly',
#  'stated',
#  'deaths',
#  'o…',
#  'Apparently',
#  'trucks',
#  'escorted',
#  'Marshals',
#  '🤞🤞',
#  'stay',
#  'safe',
#  'hijacking',
#  'o…',
#  'newly',
#  'approved',
#  'start',
#  'distributed',
#  'states',
#  'Dec',
#  '14',
#  'according',
#  'of…',
#  'know',
#  'Trumpkins',
#  'like',
#  'informed',
#  'goes:',
#  '1)',
#  'vaccine',
#  'developed',
#  'in…',
#  'firm',
#  'Acuitas',
#  'heart',
#  'great',
#  'story',
#  'helped',
#  'early',
#  'wi…',
#  'trucks',
#  'loaded',
#  'Pfizer’s',
#  'coronavirus',
#  'shot',
#  'pulled',
#  'Michigan',
#  'warehouse',
#  'early',
#  'Sunday',
#  '—',
#  'starting',
#  't…',
#  'Thanks',
#  'bringing',
#  'fresh',
#  'air',
#  'positivity',
#  'God’s',
#  'hand',
#  'pushing',
#  'forw…',
#  'shipment',
#  'PfizerBioNTech',
#  'coronavirus',
#  'vaccine',
#  'leaves',
#  'Michigan',
#  'facility',
#  'Happy',
#  'relieved',
#  '–',
#  'amazing',
#  'work',
#  'since…',
#  'companies',
#  'submitted',
#  'applicat…',
#  'Food',
#  'Drug',
#  'Administration',
#  '(FDA)',
#  'issued',
#  'yesterday',
#  'emergency',
#  'use',
#  'authorization',
#  'PfizerBioN…',
#  'COVID',
#  '19',
#  'Vaccination',
#  'Latest',
#  'Update',
#  '10',
#  'months',
#  '3',
#  'weeks',
#  'case',
#  'finally',
#  'relief',
#  'Uncle',
#  'Sam',
#  'Vaccination',
#  'starts',
#  'Monday👏…',
#  'trucks',
#  'filled',
#  'hit',
#  'road',
#  '💉',
#  'Interesting',
#  'Watch:',
#  'live',
#  'coverage',
#  'loading',
#  'vaccine',
#  'Pfizer',
#  'plant',
#  'at…',
#  'people',
#  'United',
#  'Kingdom',
#  'experienced',
#  'allergic',
#  'reaction',
#  'Pfizer/BioNTech',
#  'COVID19',
#  'vaccine',
#  'Rea…',
#  '💉GPs',
#  'struggling',
#  'provide',
#  'core',
#  'services',
#  'amp',
#  'di…',
#  'shipments',
#  'vaccine',
#  'begin',
#  'arriving',
#  'states',
#  'Monday',
#  'offi…',
#  'numbers',
#  'likely',
#  'worse',
#  'holidays',
#  'offering',
#  'bright',
#  'spot',
#  'fight',
#  'the…',
#  'good',
#  'work',
#  'Ok',
#  'late',
#  'discovering',
#  'vaccines',
#  'led',
#  'by…',
#  'President',
#  'Donald',
#  'Trump',
#  'announced',
#  'vaccine',
#  'free',
#  'Americans',
#  'thanked',
#  'scienti…',
#  'hatched',
#  'Canada',
#  '(2)',
#  'vaccine',
#  'developed',
#  'Germany',
#  '(3)',
#  'Scie…',
#  'hatched',
#  'Canada',
#  '(2)',
#  'vaccine',
#  'developed',
#  'Germany',
#  '(3)',
#  'Scie…',
#  'Proving',
#  'unproven',
#  'time',
#  'constraints',
#  'hardest',
#  'Great',
#  'achievement',
#  'Pfizer',
#  'love',
#  'high',
#  'quality',
#  'infographics',
#  'getting',
#  'multiple',
#  'ideas',
#  'quickly',
#  'excellent',
#  'set',
#  'Fact…',
#  'learn',
#  'victory',
#  'good',
#  'refresher',
#  'polio',
#  'came',
#  'end',
#  'Lets',
#  'forget…',
#  'Big',
#  'Pharma',
#  'best',
#  'interests',
#  'hold',
#  'stock',
#  'amp',
#  'patients',
#  '🇬🇧',
#  'guidance',
#  'clear',
#  'now:',
#  'person',
#  'history',
#  'anaphylaxis',
#  'vaccine',
#  'medicine',
#  'o…',
#  'agency',
#  'authorizes',
#  'PfizerBioNTech',
#  'COVID19',
#  'vaccine',
#  'vaccine',
#  'administered',
#  'in…',
#  'New',
#  'PODCAST:',
#  'Vaccinating',
#  'Way',
#  'Pandemic',
#  'amp',
#  'discuss',
#  'the…',
#  'Eric',
#  'Shawn:',
#  'vaccine',
#  'record',
#  'time',
#  'thanks',
#  'al…',
#  'Facts',
#  'Senator',
#  'nice',
#  'respect',
#  'faith',
#  'tell',
#  'truth',
#  'vaccine',
#  'dev…',
#  'coming',
#  'Vaccine',
#  'soon',
#  'excited',
#  'relieved',
#  'share',
#  'I’ll',
#  'receive',
#  'Thank…',
#  'DYK:',
#  'amp',
#  'nations',
#  'approve',
#  'Fascinating',
#  'messenger',
#  'RNA',
#  'vaccine',
#  'delivery',
#  'approach',
#  'helped',
#  'enable',
#  'dramatically',
#  'shorter',
#  'time',
#  'to…',
#  'Vaccine',
#  'discovered',
#  'developed',
#  'Europe',
#  'TurkishGerman',
#  'husband',
#  'wife',
#  'Tiffany',
#  'Dover',
#  'alive',
#  '👀😃',
#  'important',
#  'day',
#  'f…',
#  'It’ll',
#  'interesting',
#  'postvaccine',
#  'birth',
#  'rates',
#  ...]

# %%
# Get Most Commonest Keywords
from collections import Counter
def get_tokens(docx,num=30):
    word_tokens = Counter(docx)
    most_common = word_tokens.most_common(num)
    result = dict(most_common)
    return result
get_tokens(pos_tokens)
# Out:
# {'vaccine': 1355,
#  'dose': 748,
#  'today': 349,
#  'Pfizer': 278,
#  'got': 273,
#  'COVID19': 233,
#  'effective': 215,
#  'amp': 210,
#  'received': 209,
#  'vaccines': 203,
#  'doses': 184,
#  'shot': 182,
#  'new': 177,
#  'second': 177,
#  'people': 175,
#  'vaccinated': 174,
#  'vaccination': 163,
#  'Vaccine': 163,
#  'jab': 149,
#  'Thanks': 147,
#  '2nd': 147,
#  'Got': 138,
#  'good': 137,
#  'Covid19': 136,
#  '💉': 132,
#  'Thank': 132,
#  'day': 118,
#  'the…': 109,
#  '1st': 107,
#  '2': 105}

# %%
most_common_pos_words = get_tokens(pos_tokens)
most_common_neg_words = get_tokens(neg_tokens)
most_common_neut_words = get_tokens(neut_tokens)
# Plot with seaborn
neg_df = pd.DataFrame(most_common_neg_words.items(),columns=['words','scores'])
neg_df
# Out:
#           words  scores
# 0       vaccine     246
# 1          dose     113
# 2        Pfizer      72
# 3           2nd      62
# 4           amp      58
# 5           arm      51
# 6        people      51
# 7         today      46
# 8        second      45
# 9          shot      43
# 10      Vaccine      40
# 11     vaccines      40
# 12         aged      40
# 13     received      38
# 14            1      38
# 15          1st      37
# 16          got      36
# 17       little      34
# 18  vaccination      32
# 19        hours      31
# 20      effects      30
# 21      COVID19      29
# 22         days      29
# 23      getting      29
# 24          day      28
# 25         like      28
# 26            2      28
# 27         long      28
# 28   vaccinated      28
# 29         sore      26

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='words',y='scores',data=neg_df)
plt.xticks(rotation=45)
plt.show()

# %%
# Plot with seaborn
pos_df = pd.DataFrame(most_common_pos_words.items(),columns=['words','scores'])
plt.figure(figsize=(20,10))
sns.barplot(x='words',y='scores',data=pos_df)
plt.xticks(rotation=45)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128137 (\N{SYRINGE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Plot with seaborn
neut_df = pd.DataFrame(most_common_neut_words.items(),columns=['words','scores'])
plt.figure(figsize=(20,10))
sns.barplot(x='words',y='scores',data=neut_df)
plt.xticks(rotation=45)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128137 (\N{SYRINGE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
### Word Cloud
from wordcloud import WordCloud
def plot_wordcloud(docx):
    plt.figure(figsize=(20,10))
    mywordcloud = WordCloud().generate(docx)
    plt.imshow(mywordcloud,interpolation='bilinear')
    plt.axis('off')
    plt.show()
pos_docx = ' '.join(pos_tokens)
neg_docx = ' '.join(neg_tokens)
neu_docx = ' '.join(neut_tokens)

# %%
plot_wordcloud(neg_docx)

# %%
plot_wordcloud(neu_docx)

# %%
plot_wordcloud(pos_docx)

# %%
fig = plt.figure(figsize=(7,7))
colors = ("yellowgreen", "gold", "red")
wp = {'linewidth':2, 'edgecolor':"black"}
tags = df['sentiment'].value_counts()
explode = (0.1,0.1,0.1)
tags.plot(kind='pie', autopct='%1.1f%%', shadow=True, colors = colors,
         startangle=90, wedgeprops = wp, explode = explode, label='')
plt.title('Distribution of sentiments')
# Out:
# Text(0.5, 1.0, 'Distribution of sentiments')

# %%
fig = plt.figure(figsize=(5,5))
sns.countplot(x='sentiment', data = df)
# Out:
# <Axes: xlabel='sentiment', ylabel='count'>

# %%
vect = CountVectorizer(ngram_range=(1,2)).fit(df['text'])
feature_names = vect.get_feature_names_out#
#print("Number of features: {}\n".format(len(feature_names)))
#print("First 20 features:\n {}".format(feature_names[:20]))

# %%
X = df['text']
Y = df['sentiment']
X = vect.transform(X)
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
print("Size of x_train:", (x_train.shape))
print("Size of y_train:", (y_train.shape))
print("Size of x_test:", (x_test.shape))
print("Size of y_test:", (y_test.shape))
# Out:
# Size of x_train: (8816, 113986)
# Size of y_train: (8816,)
# Size of x_test: (2204, 113986)
# Size of y_test: (2204,)

# %%
import warnings
warnings.filterwarnings('ignore')
logreg = LogisticRegression()
logreg.fit(x_train, y_train)
logreg_pred = logreg.predict(x_test)
logreg_acc = accuracy_score(logreg_pred, y_test)
print("Test accuracy: {:.2f}%".format(logreg_acc*100))
# Out:
# Test accuracy: 82.89%

# %%
print(confusion_matrix(y_test, logreg_pred))
print("\n")
print(classification_report(y_test, logreg_pred))
# Out:
# [[ 68 123  38]
#  [ 10 987  35]
#  [ 11 160 772]]
#
#
#               precision    recall  f1-score   support
#
#     Negative       0.76      0.30      0.43       229
#      Neutral       0.78      0.96      0.86      1032
#     Positive       0.91      0.82      0.86       943
#
#     accuracy                           0.83      2204
#    macro avg       0.82      0.69      0.72      2204
# weighted avg       0.83      0.83      0.82      2204

# %%
style.use('classic')
cm = confusion_matrix(y_test, logreg_pred, labels=logreg.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels=logreg.classes_)
disp.plot()

# %%
from sklearn.model_selection import GridSearchCV
param_grid={'C':[0.001, 0.01, 0.1, 1, 10]}
grid = GridSearchCV(LogisticRegression(), param_grid)
grid.fit(x_train, y_train)
# Out:
# GridSearchCV(estimator=LogisticRegression(),
#              param_grid={'C': [0.001, 0.01, 0.1, 1, 10]})

# %%
print("Best parameters:", grid.best_params_)
# Out:
# Best parameters: {'C': 10}

# %%
y_pred = grid.predict(x_test)
logreg_acc = accuracy_score(y_pred, y_test)
print("Test accuracy: {:.2f}%".format(logreg_acc*100))
# Out:
# Test accuracy: 83.89%

# %%
print(confusion_matrix(y_test, y_pred))
print("\n")
print(classification_report(y_test, y_pred))
# Out:
# [[ 78 112  39]
#  [ 11 990  31]
#  [ 12 150 781]]
#
#
#               precision    recall  f1-score   support
#
#     Negative       0.77      0.34      0.47       229
#      Neutral       0.79      0.96      0.87      1032
#     Positive       0.92      0.83      0.87       943
#
#     accuracy                           0.84      2204
#    macro avg       0.83      0.71      0.74      2204
# weighted avg       0.84      0.84      0.83      2204

# %%
from sklearn.svm import LinearSVC
SVCmodel = LinearSVC()
SVCmodel.fit(x_train, y_train)
# Out:
# LinearSVC()

# %%
svc_pred = SVCmodel.predict(x_test)
svc_acc = accuracy_score(svc_pred, y_test)
print("test accuracy: {:.2f}%".format(svc_acc*100))
# Out:
# test accuracy: 84.53%

# %%
print(confusion_matrix(y_test, svc_pred))
print("\n")
print(classification_report(y_test, svc_pred))
# Out:
# [[ 86 106  37]
#  [ 13 989  30]
#  [ 16 139 788]]
#
#
#               precision    recall  f1-score   support
#
#     Negative       0.75      0.38      0.50       229
#      Neutral       0.80      0.96      0.87      1032
#     Positive       0.92      0.84      0.88       943
#
#     accuracy                           0.85      2204
#    macro avg       0.82      0.72      0.75      2204
# weighted avg       0.85      0.85      0.84      2204

# %%
grid = {
    'C':[0.01, 0.1, 1, 10],
    'kernel':["linear","poly","rbf","sigmoid"],
    'degree':[1,3,5,7],
    'gamma':[0.01,1]
}
grid = GridSearchCV(SVCmodel, param_grid)
grid.fit(x_train, y_train)
# Out:
# GridSearchCV(estimator=LinearSVC(), param_grid={'C': [0.001, 0.01, 0.1, 1, 10]})

# %%
print("Best parameter:", grid.best_params_)
# Out:
# Best parameter: {'C': 10}

# %%
y_pred = grid.predict(x_test)
logreg_acc = accuracy_score(y_pred, y_test)
print("Test accuracy: {:.2f}%".format(logreg_acc*100))
# Out:
# Test accuracy: 84.57%

# %%
print(confusion_matrix(y_test, y_pred))
print("\n")
print(classification_report(y_test, y_pred))
# Out:
# [[ 87 106  36]
#  [ 13 990  29]
#  [ 19 137 787]]
#
#
#               precision    recall  f1-score   support
#
#     Negative       0.73      0.38      0.50       229
#      Neutral       0.80      0.96      0.87      1032
#     Positive       0.92      0.83      0.88       943
#
#     accuracy                           0.85      2204
#    macro avg       0.82      0.72      0.75      2204
# weighted avg       0.85      0.85      0.84      2204

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
